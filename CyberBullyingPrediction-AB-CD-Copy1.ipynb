# %%
import pandas as pd

# %%
import numpy as np

# %%
import string

# %%
import nltk

# %%
from nltk.corpus import stopwords

# %%
from nltk.tokenize import word_tokenize

# %%
from nltk.stem import WordNetLemmatizer

# %%
from nltk.classify import DecisionTreeClassifier

# %%
from nltk import metrics

# %%
from nltk.metrics.scores import (accuracy, precision, recall, f_measure)

# %%
from nltk.classify import MaxentClassifier

# %%
from nltk.classify import SklearnClassifier

# %%
from sklearn.svm import SVC

# %%
from nltk import bigrams, trigrams

# %%
from nltk.collocations import BigramCollocationFinder

# %%
from nltk.metrics import BigramAssocMeasures

# %%
from nltk.collocations import TrigramCollocationFinder

# %%
from nltk.metrics import TrigramAssocMeasures

# %%
from nltk.corpus import stopwords

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import collections

# %%
import random

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from nltk.metrics import ConfusionMatrix

# %%
df1 = pd.read_csv("CyberBullyingDataset.csv")

# %%
df1.head()
# Out:
#                                                Tweet    Text Label
# 0  .omg why are poc wearing fugly blue contacts s...  Non-Bullying
# 1  .Sorry but most of the runners popular right n...  Non-Bullying
# 2  .those jeans are hideous, and I?m afraid he?s ...  Non-Bullying
# 3  .I had to dress up for a presentation in class...  Non-Bullying
# 4  .Am I the only one who thinks justin bieber is...  Non-Bullying

# %%
df1.tail()
# Out:
#                                                   Tweet Text Label
# 1060  No we are not, But you are a race baiting libt...   Bullying
# 1061  you wont get anyone for this challenge., after...   Bullying
# 1062  I will follow you if you are not a libtard,Mus...   Bullying
# 1063  michaelianblack Ur a child, an ostrich w/ your...   Bullying
# 1064  FoxNews. not to all the ppl I know that live t...   Bullying

# %%
df1.sample(10)
# Out:
#                                                  Tweet    Text Label
# 419                            If you?re a snitch kys.  Non-Bullying
# 532  .probably not gonna get my food anytime soon b...  Non-Bullying
# 477  I hope I'm wrong.", 'When you complain about p...  Non-Bullying
# 304   If i was then you would be the teacher of the...  Non-Bullying
# 840                                             Kys x.      Bullying
# 262  Lecture April 11, 5:30pm Joseph Winters "Betwe...  Non-Bullying
# 75   .GUESS WHICH DUMBASS IS OFFICIALLY OUT OF ENGI...  Non-Bullying
# 910  .realDonaldTrump I call Bullshit #presidentshi...      Bullying
# 291  BlueManc71 You said Hanzo, it's Genji!", "I'm ...  Non-Bullying
# 346  I know who lol he also is Kilgrave.', 'And the...  Non-Bullying

# %%
Tweet = []
Labels = []

# %%
for row in df1["Tweet"]:
    words = word_tokenize(row)
    clean_words = [word.lower() for word in words if word not in set(string.punctuation)]
    english_stops = set(stopwords.words('english'))
    characters_to_remove = ["''",'``',"rt","https","’","“","”","\u200b","--","n't","'s","...","//t.c" ]
    clean_words = [word for word in clean_words if word not in english_stops]
    clean_words = [word for word in clean_words if word not in set(characters_to_remove)]
    #Lematise words
    wordnet_lemmatizer = WordNetLemmatizer()
    lemma_list = [wordnet_lemmatizer.lemmatize(word) for word in clean_words]
    Tweet.append(lemma_list)

    for row in df1["Text Label"]:
        Labels.append(row)

# %%
combined = zip(Tweet, Labels)

# %%
def bag_of_words(words):
    return dict([(word, True) for word in words])

# %%
Final_Data = []

# %%
for r, v in combined:
    bag_of_words(r)
    Final_Data.append((bag_of_words(r),v))

# %%
random.shuffle(Final_Data)
print(len(Final_Data))
# Out:
# 1065

# %%
train_set, test_set = Final_Data[0:746], Final_Data[746:]

# %%
refsets = collections. defaultdict(set)

# %%
testsets = collections.defaultdict(set)

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
wlabels = []
wtests = []

# %%
for i, (feats, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = classifier.classify(feats)
    testsets[observed].add(i)
    wlabels.append(label)
    wtests.append(observed)

# %%
refsets
# Out:
# defaultdict(set,
#             {'Bullying': {0,
#               3,
#               4,
#               7,
#               8,
#               11,
#               12,
#               13,
#               15,
#               16,
#               20,
#               21,
#               23,
#               25,
#               29,
#               30,
#               31,
#               32,
#               34,
#               36,
#               37,
#               39,
#               43,
#               45,
#               46,
#               50,
#               53,
#               55,
#               57,
#               60,
#               61,
#               62,
#               65,
#               66,
#               68,
#               70,
#               76,
#               78,
#               79,
#               81,
#               84,
#               86,
#               88,
#               92,
#               93,
#               97,
#               104,
#               105,
#               106,
#               107,
#               116,
#               117,
#               118,
#               124,
#               126,
#               129,
#               132,
#               133,
#               135,
#               137,
#               138,
#               139,
#               142,
#               143,
#               148,
#               151,
#               154,
#               156,
#               158,
#               161,
#               168,
#               169,
#               170,
#               174,
#               175,
#               176,
#               177,
#               178,
#               180,
#               185,
#               186,
#               187,
#               194,
#               197,
#               198,
#               201,
#               204,
#               205,
#               207,
#               209,
#               210,
#               214,
#               218,
#               221,
#               223,
#               230,
#               231,
#               232,
#               240,
#               244,
#               246,
#               250,
#               253,
#               255,
#               257,
#               260,
#               261,
#               266,
#               267,
#               270,
#               271,
#               273,
#               274,
#               277,
#               278,
#               279,
#               281,
#               282,
#               286,
#               287,
#               289,
#               292,
#               293,
#               296,
#               299,
#               301,
#               303,
#               304,
#               306,
#               310,
#               312,
#               317},
#              'Non-Bullying': {1,
#               2,
#               5,
#               6,
#               9,
#               10,
#               14,
#               17,
#               18,
#               19,
#               22,
#               24,
#               26,
#               27,
#               28,
#               33,
#               35,
#               38,
#               40,
#               41,
#               42,
#               44,
#               47,
#               48,
#               49,
#               51,
#               52,
#               54,
#               56,
#               58,
#               59,
#               63,
#               64,
#               67,
#               69,
#               71,
#               72,
#               73,
#               74,
#               75,
#               77,
#               80,
#               82,
#               83,
#               85,
#               87,
#               89,
#               90,
#               91,
#               94,
#               95,
#               96,
#               98,
#               99,
#               100,
#               101,
#               102,
#               103,
#               108,
#               109,
#               110,
#               111,
#               112,
#               113,
#               114,
#               115,
#               119,
#               120,
#               121,
#               122,
#               123,
#               125,
#               127,
#               128,
#               130,
#               131,
#               134,
#               136,
#               140,
#               141,
#               144,
#               145,
#               146,
#               147,
#               149,
#               150,
#               152,
#               153,
#               155,
#               157,
#               159,
#               160,
#               162,
#               163,
#               164,
#               165,
#               166,
#               167,
#               171,
#               172,
#               173,
#               179,
#               181,
#               182,
#               183,
#               184,
#               188,
#               189,
#               190,
#               191,
#               192,
#               193,
#               195,
#               196,
#               199,
#               200,
#               202,
#               203,
#               206,
#               208,
#               211,
#               212,
#               213,
#               215,
#               216,
#               217,
#               219,
#               220,
#               222,
#               224,
#               225,
#               226,
#               227,
#               228,
#               229,
#               233,
#               234,
#               235,
#               236,
#               237,
#               238,
#               239,
#               241,
#               242,
#               243,
#               245,
#               247,
#               248,
#               249,
#               251,
#               252,
#               254,
#               256,
#               258,
#               259,
#               262,
#               263,
#               264,
#               265,
#               268,
#               269,
#               272,
#               275,
#               276,
#               280,
#               283,
#               284,
#               285,
#               288,
#               290,
#               291,
#               294,
#               295,
#               297,
#               298,
#               300,
#               302,
#               305,
#               307,
#               308,
#               309,
#               311,
#               313,
#               314,
#               315,
#               316,
#               318}})

# %%
testsets
# Out:
# defaultdict(set,
#             {'Non-Bullying': {0,
#               1,
#               4,
#               5,
#               6,
#               7,
#               8,
#               9,
#               10,
#               14,
#               17,
#               20,
#               22,
#               24,
#               26,
#               27,
#               29,
#               31,
#               33,
#               35,
#               38,
#               39,
#               41,
#               42,
#               44,
#               48,
#               51,
#               52,
#               53,
#               54,
#               56,
#               58,
#               61,
#               62,
#               66,
#               67,
#               68,
#               69,
#               71,
#               72,
#               73,
#               74,
#               76,
#               77,
#               78,
#               81,
#               82,
#               86,
#               87,
#               90,
#               91,
#               92,
#               94,
#               95,
#               96,
#               100,
#               101,
#               103,
#               106,
#               108,
#               110,
#               113,
#               114,
#               115,
#               116,
#               121,
#               123,
#               124,
#               128,
#               129,
#               130,
#               131,
#               132,
#               134,
#               136,
#               140,
#               141,
#               142,
#               146,
#               147,
#               150,
#               152,
#               153,
#               154,
#               155,
#               156,
#               157,
#               160,
#               162,
#               163,
#               164,
#               165,
#               166,
#               173,
#               174,
#               176,
#               177,
#               179,
#               180,
#               182,
#               184,
#               186,
#               187,
#               188,
#               190,
#               192,
#               193,
#               195,
#               196,
#               199,
#               200,
#               201,
#               203,
#               206,
#               210,
#               213,
#               215,
#               216,
#               217,
#               219,
#               220,
#               224,
#               226,
#               227,
#               228,
#               229,
#               233,
#               236,
#               237,
#               239,
#               241,
#               243,
#               247,
#               248,
#               250,
#               255,
#               256,
#               258,
#               259,
#               262,
#               263,
#               264,
#               265,
#               268,
#               269,
#               275,
#               276,
#               278,
#               280,
#               282,
#               284,
#               286,
#               287,
#               288,
#               291,
#               292,
#               293,
#               294,
#               297,
#               298,
#               300,
#               303,
#               306,
#               308,
#               309,
#               311,
#               313,
#               316,
#               318},
#              'Bullying': {2,
#               3,
#               11,
#               12,
#               13,
#               15,
#               16,
#               18,
#               19,
#               21,
#               23,
#               25,
#               28,
#               30,
#               32,
#               34,
#               36,
#               37,
#               40,
#               43,
#               45,
#               46,
#               47,
#               49,
#               50,
#               55,
#               57,
#               59,
#               60,
#               63,
#               64,
#               65,
#               70,
#               75,
#               79,
#               80,
#               83,
#               84,
#               85,
#               88,
#               89,
#               93,
#               97,
#               98,
#               99,
#               102,
#               104,
#               105,
#               107,
#               109,
#               111,
#               112,
#               117,
#               118,
#               119,
#               120,
#               122,
#               125,
#               126,
#               127,
#               133,
#               135,
#               137,
#               138,
#               139,
#               143,
#               144,
#               145,
#               148,
#               149,
#               151,
#               158,
#               159,
#               161,
#               167,
#               168,
#               169,
#               170,
#               171,
#               172,
#               175,
#               178,
#               181,
#               183,
#               185,
#               189,
#               191,
#               194,
#               197,
#               198,
#               202,
#               204,
#               205,
#               207,
#               208,
#               209,
#               211,
#               212,
#               214,
#               218,
#               221,
#               222,
#               223,
#               225,
#               230,
#               231,
#               232,
#               234,
#               235,
#               238,
#               240,
#               242,
#               244,
#               245,
#               246,
#               249,
#               251,
#               252,
#               253,
#               254,
#               257,
#               260,
#               261,
#               266,
#               267,
#               270,
#               271,
#               272,
#               273,
#               274,
#               277,
#               279,
#               281,
#               283,
#               285,
#               289,
#               290,
#               295,
#               296,
#               299,
#               301,
#               302,
#               304,
#               305,
#               307,
#               310,
#               312,
#               314,
#               315,
#               317}})

# %%
cm = ConfusionMatrix(wlabels, wtests)
print(cm)
# Out:
#              |       N |
#              |       o |
#              |       n |
#              |       - |
#              |   B   B |
#              |   u   u |
#              |   l   l |
#              |   l   l |
#              |   y   y |
#              |   i   i |
#              |   n   n |
#              |   g   g |
# -------------+---------+
#     Bullying | <88> 44 |
# Non-Bullying |  62<125>|
# -------------+---------+
# (row = reference; col = test)

# %%
wlabels
# Out:
# ['Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying']

# %%
wtests
# Out:
# ['Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Bullying',
#  'Non-Bullying',
#  'Bullying',
#  'Non-Bullying']

# %%
print("Naive Bayes Performance with Unigrams ")
# Out:
# Naive Bayes Performance with Unigrams

# %%
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# Accuracy: 0.6677115987460815

# %%
nb_classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
nbrefset = collections.defaultdict(set)

# %%
nbtestset = collections.defaultdict(set)

# %%
for i, (feats, label) in enumerate(test_set):
    nbrefset[label].add(i)
    observed = nb_classifier.classify(feats)
    nbtestset[observed].add(i)

# %%
print("Unigram Naive Bayes Classifier Recall")
print('Bullying recall:', recall(nbtestset['Bullying'], nbrefset['Bullying']))
# Out:
# Unigram Naive Bayes Classifier Recall
# Bullying recall: 0.5866666666666667

# %%
classifier.show_most_informative_features(n=10)
# Out:
# Most Informative Features
#                      low = True           Bullyi : Non-Bu =     13.7 : 1.0
#                worthless = True           Bullyi : Non-Bu =      8.2 : 1.0
#                  someone = True           Non-Bu : Bullyi =      8.1 : 1.0
#                       iq = True           Bullyi : Non-Bu =      6.9 : 1.0
#                    sorry = True           Bullyi : Non-Bu =      6.6 : 1.0
#                      kid = True           Bullyi : Non-Bu =      6.6 : 1.0
#                     live = True           Bullyi : Non-Bu =      5.6 : 1.0
#                       ur = True           Bullyi : Non-Bu =      5.6 : 1.0
#                   retard = True           Bullyi : Non-Bu =      5.1 : 1.0
#                 everyone = True           Non-Bu : Bullyi =      5.0 : 1.0

# %%
dt_classifier = DecisionTreeClassifier.train(train_set, 
                                             binary=True, 
                                             entropy_cutoff=0.8, 
                                             depth_cutoff=5, 
                                             support_cutoff=30)

# %%
refset = collections.defaultdict(set)

# %%
testset = collections.defaultdict(set)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = dt_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("Unigram Decision Tree Classifier Recall")
print('Bullying recall:', recall(testset['Bullying'], refset['Bullying']))
# Out:
# Unigram Decision Tree Classifier Recall
# Bullying recall: 0.7192982456140351

# %%
logit_classifier = MaxentClassifier.train(train_set, algorithm='gis', trace=0, max_iter=10, min_lldelta=0.5)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = logit_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("Unigram Maxent Classifier Classifier Recall")
print('Bullying recall:', recall(testset['Bullying'], refset['Bullying']))
# Out:
# Unigram Maxent Classifier Classifier Recall
# Bullying recall: 0.6666666666666666

# %%
SVM_classifier = SklearnClassifier(SVC(), sparse=False).train(train_set)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = SVM_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("SVM Classifier Classifier Recall")
print('Bullying recall:', recall(testset['Bullying'], refset['Bullying']))
# Out:
# SVM Classifier Classifier Recall
# Bullying recall: 0.6434108527131783

# %%
combined = zip(Tweet,Labels)

# %%
def bag_of_bigrams_words(words, score_fn=BigramAssocMeasures.chi_sq, n=200):
    bigram_finder = BigramCollocationFinder.from_words(words)  
    bigrams = bigram_finder.nbest(score_fn, n)  
    return bag_of_words(bigrams)

# %%
Final_Data2 =[]

# %%
for z, e in combined:
    bag_of_bigrams_words(z)
    Final_Data2.append((bag_of_bigrams_words(z),e))

# %%
random.shuffle(Final_Data2)
print(len(Final_Data2))
# Out:
# 1065

# %%
train_set, test_set = Final_Data2[0:747], Final_Data2[747:]

# %%
refsets = collections. defaultdict(set)
testsets = collections.defaultdict(set)

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
for i, (feats, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = classifier.classify(feats)
    testsets[observed].add(i)

# %%
print("Naive Bayes Performance with Bigrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# Naive Bayes Performance with Bigrams
# Accuracy: 0.6509433962264151

# %%
classifier.show_most_informative_features(n=10)
# Out:
# Most Informative Features
#            ('low', 'iq') = True           Bullyi : Non-Bu =     14.9 : 1.0
#        ('piece', 'shit') = True           Bullyi : Non-Bu =      8.4 : 1.0
#   ('worthless', 'piece') = True           Bullyi : Non-Bu =      5.3 : 1.0
#    ('pathetic', 'loser') = True           Bullyi : Non-Bu =      4.7 : 1.0
#      ('fucking', 'cunt') = True           Bullyi : Non-Bu =      3.6 : 1.0
#            ('gon', 'na') = True           Bullyi : Non-Bu =      3.6 : 1.0
# ('theellenshow', '.kamalaharris') = True           Bullyi : Non-Bu =      2.6 : 1.0
#    ('fucking', 'retard') = True           Bullyi : Non-Bu =      2.6 : 1.0
#         ('look', 'like') = True           Bullyi : Non-Bu =      2.0 : 1.0
#       ('nobody', 'care') = True           Bullyi : Non-Bu =      1.9 : 1.0

# %%
dt_classifier = DecisionTreeClassifier.train(train_set, 
                                             binary=True, 
                                             entropy_cutoff=0.8, 
                                             depth_cutoff=5, 
                                             support_cutoff=30)

# %%
refset = collections.defaultdict(set)
testset = collections.defaultdict(set)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = dt_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("Decision Tree Performance with Bigrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# Decision Tree Performance with Bigrams
# Accuracy: 0.6509433962264151

# %%
logit_classifier = MaxentClassifier.train(train_set, algorithm='gis', trace=0, max_iter=10, min_lldelta=0.5)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = logit_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("Maxent Performance with Bigrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# Maxent Performance with Bigrams
# Accuracy: 0.6509433962264151

# %%
print("Bigrams Maxent Recall")
print('Bullying recall:', recall(testset['Bullying'], refset['Bullying']))
# Out:
# Bigrams Maxent Recall
# Bullying recall: 0.7

# %%
SVM_classifier = SklearnClassifier(SVC(), sparse=False).train(train_set)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = SVM_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("SVM Performance with Bigrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# SVM Performance with Bigrams
# Accuracy: 0.6509433962264151

# %%
combined = zip(Tweet,Labels)

# %%
def bag_of_trigrams_words(words, score_fn=TrigramAssocMeasures.chi_sq, n=200):
    trigram_finder = TrigramCollocationFinder.from_words(words)  
    trigrams = trigram_finder.nbest(score_fn, n)  
    return bag_of_words(trigrams)

# %%
Final_Data3 =[]

# %%
for z, e in combined:
    bag_of_trigrams_words(z)
    Final_Data3.append((bag_of_trigrams_words(z),e))

# %%
random.shuffle(Final_Data3)
print(len(Final_Data3))
# Out:
# 1065

# %%
train_set, test_set = Final_Data3[0:747], Final_Data3[747:]

# %%
refsets = collections. defaultdict(set)
testsets = collections.defaultdict(set)

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
for i, (feats, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = classifier.classify(feats)
    testsets[observed].add(i)

# %%
print("Naive Bayes Performance with Trigrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# Naive Bayes Performance with Trigrams
# Accuracy: 0.6477987421383647

# %%
print('bullying precision:', precision(refsets['Bullying'], testsets['Bullying']))
print('bullying recall:', recall(refsets['Bullying'], testsets['Bullying']))
# Out:
# bullying precision: 0.8333333333333334
# bullying recall: 0.04310344827586207

# %%
classifier.show_most_informative_features(n=10)
# Out:
# Most Informative Features
# ('worthless', 'piece', 'shit') = True           Bullyi : Non-Bu =      6.4 : 1.0
# ('look', 'european', 'country') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('another', 'low', 'iq') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('think', 'illegals', 'threat') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('threat', 'idiot', "'one") = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('need', 'look', 'european') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('bitch', 'fugly', 'smoking') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('illegals', 'threat', 'idiot') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ("'one", 'need', 'look') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('dope', 'like', 'junky') = True           Bullyi : Non-Bu =      1.4 : 1.0

# %%
dt_classifier = DecisionTreeClassifier.train(train_set, 
                                             binary=True, 
                                             entropy_cutoff=0.8, 
                                             depth_cutoff=5, 
                                             support_cutoff=30)

# %%
refset = collections.defaultdict(set)
testset = collections.defaultdict(set)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = dt_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("Decision Tree Performance with Trigrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# Decision Tree Performance with Trigrams
# Accuracy: 0.6477987421383647

# %%
logit_classifier = MaxentClassifier.train(train_set, algorithm='gis', trace=0, max_iter=10, min_lldelta=0.5)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = logit_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("Maxent Performance with Trigrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# Maxent Performance with Trigrams
# Accuracy: 0.6477987421383647

# %%
SVM_classifier = SklearnClassifier(SVC(), sparse=False).train(train_set)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = SVM_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("SVM Performance with Trigrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# SVM Performance with Trigrams
# Accuracy: 0.6477987421383647

# %%
combined = zip(Tweet,Labels)

# %%
def bigrams_words(words, score_fn=BigramAssocMeasures.chi_sq, n=200):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    return bigrams

# %%
def trigrams_words(words, score_fn=TrigramAssocMeasures.chi_sq, n=200):
    trigram_finder = TrigramCollocationFinder.from_words(words)
    trigrams = trigram_finder.nbest(score_fn, n)
    return trigrams

# %%
def bag_of_Ngrams_words(words):
    bigramBag = bigrams_words(words)
    
    for b in range(0,len(bigramBag)):
        bigramBag[b]=' '.join(bigramBag[b])
   
    trigramBag = trigrams_words(words)
    for t in range(0,len(trigramBag)):
        trigramBag[t]=' '.join(trigramBag[t])

    return bag_of_words(trigramBag + bigramBag + words)

# %%
Final_Data4 =[]

# %%
for z, e in combined:
    bag_of_Ngrams_words(z)
    Final_Data4.append((bag_of_Ngrams_words(z),e))

# %%
random.shuffle(Final_Data4)
print(len(Final_Data4))
# Out:
# 1065

# %%
train_set, test_set = Final_Data4[0:747], Final_Data4[747:]

# %%
refsets = collections. defaultdict(set)
testsets = collections.defaultdict(set)

# %%
for i, (feats, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = classifier.classify(feats)
    testsets[observed].add(i)

# %%
print("Naive Bayes Performance with Ngrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# Naive Bayes Performance with Ngrams
# Accuracy: 0.6037735849056604

# %%
classifier.show_most_informative_features(n=10)
# Out:
# Most Informative Features
# ('worthless', 'piece', 'shit') = True           Bullyi : Non-Bu =      6.4 : 1.0
# ('look', 'european', 'country') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('another', 'low', 'iq') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('think', 'illegals', 'threat') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('threat', 'idiot', "'one") = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('need', 'look', 'european') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('bitch', 'fugly', 'smoking') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('illegals', 'threat', 'idiot') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ("'one", 'need', 'look') = True           Bullyi : Non-Bu =      1.4 : 1.0
# ('dope', 'like', 'junky') = True           Bullyi : Non-Bu =      1.4 : 1.0

# %%
train_set
# Out:
# [({'low iq man': True,
#    'president really low': True,
#    'really low iq': True,
#    'iq man': True,
#    'low iq': True,
#    'president really': True,
#    'really low': True,
#    'president': True,
#    'really': True,
#    'low': True,
#    'iq': True,
#    'man': True},
#   'Bullying'),
#  ({'anthro soon removed': True,
#    'cause care money': True,
#    'oder since putting': True,
#    'putting anthro soon': True,
#    'removed tix cause': True,
#    'since putting anthro': True,
#    'soon removed tix': True,
#    'support oder since': True,
#    'tix cause care': True,
#    'wonder support oder': True,
#    'care money ky': True,
#    'ky wonder support': True,
#    'anthro soon': True,
#    'care money': True,
#    'cause care': True,
#    'oder since': True,
#    'putting anthro': True,
#    'removed tix': True,
#    'since putting': True,
#    'soon removed': True,
#    'support oder': True,
#    'tix cause': True,
#    'wonder support': True,
#    'ky wonder': True,
#    'money ky': True,
#    'ky': True,
#    'wonder': True,
#    'support': True,
#    'oder': True,
#    'since': True,
#    'putting': True,
#    'anthro': True,
#    'soon': True,
#    'removed': True,
#    'tix': True,
#    'cause': True,
#    'care': True,
#    'money': True},
#   'Non-Bullying'),
#  ({'.dloesch .bluelivesmatter mean': True,
#    'glennbeck .dloesch .bluelivesmatter': True,
#    '.bluelivesmatter mean': True,
#    '.dloesch .bluelivesmatter': True,
#    'glennbeck .dloesch': True,
#    'glennbeck': True,
#    '.dloesch': True,
#    '.bluelivesmatter': True,
#    'mean': True},
#   'Bullying'),
#  ({'guess nasty libtard': True,
#    'kamalaharris guess nasty': True,
#    'libtard like rest': True,
#    'like rest snowflakes..': True,
#    'nasty libtard like': True,
#    'guess nasty': True,
#    'kamalaharris guess': True,
#    'libtard like': True,
#    'like rest': True,
#    'nasty libtard': True,
#    'rest snowflakes..': True,
#    'kamalaharris': True,
#    'guess': True,
#    'nasty': True,
#    'libtard': True,
#    'like': True,
#    'rest': True,
#    'snowflakes..': True},
#   'Bullying'),
#  ({"'m wrong 'when": True,
#    "'when complain player": True,
#    'complain player team': True,
#    "hope 'm wrong": True,
#    'player team support': True,
#    'support everyone jump': True,
#    'team support everyone': True,
#    "wrong 'when complain": True,
#    "'m wrong": True,
#    "'when complain": True,
#    'complain player': True,
#    'everyone jump': True,
#    "hope 'm": True,
#    'player team': True,
#    'support everyone': True,
#    'team support': True,
#    "wrong 'when": True,
#    'hope': True,
#    "'m": True,
#    'wrong': True,
#    "'when": True,
#    'complain': True,
#    'player': True,
#    'team': True,
#    'support': True,
#    'everyone': True,
#    'jump': True},
#   'Non-Bullying'),
#  ({"'time get twitter": True,
#    "fan 'time get": True,
#    'get twitter sideline': True,
#    "sideline 'realdonaldtrump incompet": True,
#    "twitter sideline 'realdonaldtrump": True,
#    "'realdonaldtrump incompet": True,
#    "'time get": True,
#    "fan 'time": True,
#    'get twitter': True,
#    "sideline 'realdonaldtrump": True,
#    'twitter sideline': True,
#    'fan': True,
#    "'time": True,
#    'get': True,
#    'twitter': True,
#    'sideline': True,
#    "'realdonaldtrump": True,
#    'incompet': True},
#   'Bullying'),
#  ({'beach..full seaweed shallow': True,
#    'enjoy new smyrna': True,
#    'fugly green water': True,
#    'green water shark': True,
#    'new smyrna beach..full': True,
#    'seaweed shallow fugly': True,
#    'shallow fugly green': True,
#    'shark nothing comp': True,
#    'smyrna beach..full seaweed': True,
#    'water shark nothing': True,
#    'beach..full seaweed': True,
#    'enjoy new': True,
#    'fugly green': True,
#    'green water': True,
#    'new smyrna': True,
#    'nothing comp': True,
#    'seaweed shallow': True,
#    'shallow fugly': True,
#    'shark nothing': True,
#    'smyrna beach..full': True,
#    'water shark': True,
#    'enjoy': True,
#    'new': True,
#    'smyrna': True,
#    'beach..full': True,
#    'seaweed': True,
#    'shallow': True,
#    'fugly': True,
#    'green': True,
#    'water': True,
#    'shark': True,
#    'nothing': True,
#    'comp': True},
#   'Non-Bullying'),
#  ({"'momma dawgs really": True,
#    'dawgs really pissed': True,
#    "pissed fugly '\\u0001f92c\\u0001f92f": True,
#    'really pissed fugly': True,
#    "thanks 'momma dawgs": True,
#    "'momma dawgs": True,
#    'dawgs really': True,
#    "fugly '\\u0001f92c\\u0001f92f": True,
#    'pissed fugly': True,
#    'really pissed': True,
#    "thanks 'momma": True,
#    'thanks': True,
#    "'momma": True,
#    'dawgs': True,
#    'really': True,
#    'pissed': True,
#    'fugly': True,
#    "'\\u0001f92c\\u0001f92f": True},
#   'Non-Bullying'),
#  ({'always seem straight': True,
#    'best person job': True,
#    'job always seem': True,
#    'middle-aged middle-class man': True,
#    'middle-class man .anoosh.c': True,
#    'person job always': True,
#    'seem straight white': True,
#    'straight white middle-aged': True,
#    'white middle-aged middle-class': True,
#    'always seem': True,
#    'best person': True,
#    'job always': True,
#    'man .anoosh.c': True,
#    'middle-aged middle-class': True,
#    'middle-class man': True,
#    'person job': True,
#    'seem straight': True,
#    'straight white': True,
#    'white middle-aged': True,
#    'best': True,
#    'person': True,
#    'job': True,
#    'always': True,
#    'seem': True,
#    'straight': True,
#    'white': True,
#    'middle-aged': True,
#    'middle-class': True,
#    'man': True,
#    '.anoosh.c': True},
#   'Non-Bullying'),
#  ({'address threaten writing': True,
#    'give address threaten': True,
#    'prove retard. give': True,
#    'retard. give address': True,
#    'threaten writing lol': True,
#    'tomilahren prove retard.': True,
#    'address threaten': True,
#    'give address': True,
#    'prove retard.': True,
#    'retard. give': True,
#    'threaten writing': True,
#    'tomilahren prove': True,
#    'writing lol': True,
#    'tomilahren': True,
#    'prove': True,
#    'retard.': True,
#    'give': True,
#    'address': True,
#    'threaten': True,
#    'writing': True,
#    'lol': True},
#   'Bullying'),
#  ({'better mind say': True,
#    'lil nigga better': True,
#    'little fuck boy': True,
#    'mind say little': True,
#    'nigga better mind': True,
#    'say little fuck': True,
#    'better mind': True,
#    'fuck boy': True,
#    'lil nigga': True,
#    'little fuck': True,
#    'mind say': True,
#    'nigga better': True,
#    'say little': True,
#    'lil': True,
#    'nigga': True,
#    'better': True,
#    'mind': True,
#    'say': True,
#    'little': True,
#    'fuck': True,
#    'boy': True},
#   'Bullying'),
#  ({'dog noncing retard': True,
#    'fat spengling dog': True,
#    'jason fat spengling': True,
#    'spengling dog noncing': True,
#    'true jason fat': True,
#    'yeah true jason': True,
#    'dog noncing': True,
#    'fat spengling': True,
#    'jason fat': True,
#    'noncing retard': True,
#    'spengling dog': True,
#    'true jason': True,
#    'yeah true': True,
#    'yeah': True,
#    'true': True,
#    'jason': True,
#    'fat': True,
#    'spengling': True,
#    'dog': True,
#    'noncing': True,
#    'retard': True},
#   'Bullying'),
#  ({"'re traitor country": True,
#    'country hope trump': True,
#    'hope trump sends': True,
#    'traitor country hope': True,
#    'trump sends troop': True,
#    "'re traitor": True,
#    'country hope': True,
#    'hope trump': True,
#    'sends troop': True,
#    'traitor country': True,
#    'trump sends': True,
#    "'re": True,
#    'traitor': True,
#    'country': True,
#    'hope': True,
#    'trump': True,
#    'sends': True,
#    'troop': True},
#   'Non-Bullying'),
#  ({'fuck nra low': True,
#    'iq talking point': True,
#    'low iq talking': True,
#    'nra low iq': True,
#    'fuck nra': True,
#    'iq talking': True,
#    'low iq': True,
#    'nra low': True,
#    'talking point': True,
#    'fuck': True,
#    'nra': True,
#    'low': True,
#    'iq': True,
#    'talking': True,
#    'point': True},
#   'Bullying'),
#  ({'amp m4 plus': True,
#    'disagree nowhere near': True,
#    'm3 amp m4': True,
#    'm4 plus fugly': True,
#    'near rogue m3': True,
#    'nowhere near rogue': True,
#    'rogue m3 amp': True,
#    'amp m4': True,
#    'disagree nowhere': True,
#    'm3 amp': True,
#    'm4 plus': True,
#    'near rogue': True,
#    'nowhere near': True,
#    'plus fugly': True,
#    'rogue m3': True,
#    'disagree': True,
#    'nowhere': True,
#    'near': True,
#    'rogue': True,
#    'm3': True,
#    'amp': True,
#    'm4': True,
#    'plus': True,
#    'fugly': True},
#   'Non-Bullying'),
#  ({'always much hatred': True,
#    'much hatred prejudice': True,
#    'hatred prejudice internet': True,
#    'internet exposed effective': True,
#    'internet internet exposed': True,
#    'prejudice internet internet': True,
#    'always much': True,
#    'exposed effective': True,
#    'hatred prejudice': True,
#    'much hatred': True,
#    'internet exposed': True,
#    'prejudice internet': True,
#    'internet internet': True,
#    'always': True,
#    'much': True,
#    'hatred': True,
#    'prejudice': True,
#    'internet': True,
#    'exposed': True,
#    'effective': True},
#   'Non-Bullying'),
#  ({'.like many would-be': True,
#    'authoritarian trump ignores': True,
#    'country face preferring': True,
#    'face preferring manufactur': True,
#    'ignores real threat': True,
#    'many would-be authoritarian': True,
#    'real threat country': True,
#    'threat country face': True,
#    'trump ignores real': True,
#    'would-be authoritarian trump': True,
#    '.like many': True,
#    'authoritarian trump': True,
#    'country face': True,
#    'face preferring': True,
#    'ignores real': True,
#    'many would-be': True,
#    'preferring manufactur': True,
#    'real threat': True,
#    'threat country': True,
#    'trump ignores': True,
#    'would-be authoritarian': True,
#    '.like': True,
#    'many': True,
#    'would-be': True,
#    'authoritarian': True,
#    'trump': True,
#    'ignores': True,
#    'real': True,
#    'threat': True,
#    'country': True,
#    'face': True,
#    'preferring': True,
#    'manufactur': True},
#   'Non-Bullying'),
#  ({"'you clue run": True,
#    'another low iq': True,
#    'ball juggler need': True,
#    'clue run anything': True,
#    'dancing ball juggler': True,
#    "hole 'you clue": True,
#    'iq tap dancing': True,
#    'juggler need shut': True,
#    'low iq tap': True,
#    'need shut pie': True,
#    "pie hole 'you": True,
#    'run anything bu': True,
#    'shut pie hole': True,
#    'tap dancing ball': True,
#    "'you clue": True,
#    'another low': True,
#    'anything bu': True,
#    'ball juggler': True,
#    'clue run': True,
#    'dancing ball': True,
#    "hole 'you": True,
#    'iq tap': True,
#    'juggler need': True,
#    'low iq': True,
#    'need shut': True,
#    'pie hole': True,
#    'run anything': True,
#    'shut pie': True,
#    'tap dancing': True,
#    'another': True,
#    'low': True,
#    'iq': True,
#    'tap': True,
#    'dancing': True,
#    'ball': True,
#    'juggler': True,
#    'need': True,
#    'shut': True,
#    'pie': True,
#    'hole': True,
#    "'you": True,
#    'clue': True,
#    'run': True,
#    'anything': True,
#    'bu': True},
#   'Non-Bullying'),
#  ({'approves bullying serial': True,
#    'bullying serial cheating': True,
#    'cheating lying pussy': True,
#    'dloesch yeah sure': True,
#    'god approves bullying': True,
#    'lying pussy grabbin': True,
#    'serial cheating lying': True,
#    'sure god approves': True,
#    'yeah sure god': True,
#    'approves bullying': True,
#    'bullying serial': True,
#    'cheating lying': True,
#    'dloesch yeah': True,
#    'god approves': True,
#    'lying pussy': True,
#    'pussy grabbin': True,
#    'serial cheating': True,
#    'sure god': True,
#    'yeah sure': True,
#    'dloesch': True,
#    'yeah': True,
#    'sure': True,
#    'god': True,
#    'approves': True,
#    'bullying': True,
#    'serial': True,
#    'cheating': True,
#    'lying': True,
#    'pussy': True,
#    'grabbin': True},
#   'Bullying'),
#  ({'.not p*ssy hat': True,
#    '.this look like': True,
#    'celebrity worshiping parade': True,
#    'feminism .this look': True,
#    'hat wearing celebrity': True,
#    'like .not p*ssy': True,
#    'look like .not': True,
#    'p*ssy hat wearing': True,
#    'wearing celebrity worshiping': True,
#    'worshiping parade .wake': True,
#    '.not p*ssy': True,
#    '.this look': True,
#    'celebrity worshiping': True,
#    'feminism .this': True,
#    'hat wearing': True,
#    'like .not': True,
#    'look like': True,
#    'p*ssy hat': True,
#    'parade .wake': True,
#    'wearing celebrity': True,
#    'worshiping parade': True,
#    'feminism': True,
#    '.this': True,
#    'look': True,
#    'like': True,
#    '.not': True,
#    'p*ssy': True,
#    'hat': True,
#    'wearing': True,
#    'celebrity': True,
#    'worshiping': True,
#    'parade': True,
#    '.wake': True},
#   'Bullying'),
#  ({'drink swamp water': True,
#    'make think going': True,
#    'think going away': True,
#    'used eating dung': True,
#    'away scum drink': True,
#    'doc trian nazi': True,
#    'eating dung doc': True,
#    'going away scum': True,
#    'scum drink swamp': True,
#    'scum used eating': True,
#    'swamp water scum': True,
#    'water scum used': True,
#    'doc doc trian': True,
#    'dung doc doc': True,
#    'drink swamp': True,
#    'eating dung': True,
#    'going away': True,
#    'make think': True,
#    'swamp water': True,
#    'think going': True,
#    'trian nazi': True,
#    'used eating': True,
#    'away scum': True,
#    'doc trian': True,
#    'dung doc': True,
#    'scum drink': True,
#    'scum used': True,
#    'water scum': True,
#    'doc doc': True,
#    'make': True,
#    'think': True,
#    'going': True,
#    'away': True,
#    'scum': True,
#    'drink': True,
#    'swamp': True,
#    'water': True,
#    'used': True,
#    'eating': True,
#    'dung': True,
#    'doc': True,
#    'trian': True,
#    'nazi': True},
#   'Non-Bullying'),
#  ({'among migrant fear': True,
#    'cropping among migrant': True,
#    'fear grow new': True,
#    'generation anti-semite comin': True,
#    'grow new generation': True,
#    'jew cropping among': True,
#    'migrant fear grow': True,
#    'new generation anti-semite': True,
#    'prejudice jew cropping': True,
#    'among migrant': True,
#    'anti-semite comin': True,
#    'cropping among': True,
#    'fear grow': True,
#    'generation anti-semite': True,
#    'grow new': True,
#    'jew cropping': True,
#    'migrant fear': True,
#    'new generation': True,
#    'prejudice jew': True,
#    'prejudice': True,
#    'jew': True,
#    'cropping': True,
#    'among': True,
#    'migrant': True,
#    'fear': True,
#    'grow': True,
#    'new': True,
#    'generation': True,
#    'anti-semite': True,
#    'comin': True},
#   'Non-Bullying'),
#  ({'retard': True}, 'Bullying'),
#  ({'embrace modern day': True,
#    'healtheworldin5words never embrace': True,
#    'modern day feminism': True,
#    'never embrace modern': True,
#    'day feminism': True,
#    'embrace modern': True,
#    'healtheworldin5words never': True,
#    'modern day': True,
#    'never embrace': True,
#    'healtheworldin5words': True,
#    'never': True,
#    'embrace': True,
#    'modern': True,
#    'day': True,
#    'feminism': True},
#   'Non-Bullying'),
#  ({"'people make 175000": True,
#    '175000 427000 yr': True,
#    "7086 'people make": True,
#    "cut 7086 'people": True,
#    'make 175000 427000': True,
#    'top 1 ky': True,
#    'see average tax': True,
#    '1 ky see': True,
#    '427000 yr see': True,
#    'tax cut 7086': True,
#    'average tax cu': True,
#    'average tax cut': True,
#    'ky see average': True,
#    'yr see average': True,
#    "'people make": True,
#    '1 ky': True,
#    '175000 427000': True,
#    '427000 yr': True,
#    "7086 'people": True,
#    'average tax': True,
#    'cut 7086': True,
#    'make 175000': True,
#    'see average': True,
#    'top 1': True,
#    'ky see': True,
#    'tax cu': True,
#    'tax cut': True,
#    'yr see': True,
#    'top': True,
#    '1': True,
#    'ky': True,
#    'see': True,
#    'average': True,
#    'tax': True,
#    'cut': True,
#    '7086': True,
#    "'people": True,
#    'make': True,
#    '175000': True,
#    '427000': True,
#    'yr': True,
#    'cu': True},
#   'Non-Bullying'),
#  ({"'re asshole think": True,
#    "'well bad th": True,
#    'asshole think whatever': True,
#    'lying piece shit': True,
#    'piece shit seyong': True,
#    "seyong 're asshole": True,
#    "shit seyong 're": True,
#    'think whatever want': True,
#    "want 'well bad": True,
#    "whatever want 'well": True,
#    "'re asshole": True,
#    "'well bad": True,
#    'asshole think': True,
#    'bad th': True,
#    'lying piece': True,
#    'piece shit': True,
#    "seyong 're": True,
#    'shit seyong': True,
#    'think whatever': True,
#    "want 'well": True,
#    'whatever want': True,
#    'lying': True,
#    'piece': True,
#    'shit': True,
#    'seyong': True,
#    "'re": True,
#    'asshole': True,
#    'think': True,
#    'whatever': True,
#    'want': True,
#    "'well": True,
#    'bad': True,
#    'th': True},
#   'Bullying'),
#  ({"'ve hired nazi": True,
#    'argument hang richard': True,
#    'hang richard spencer': True,
#    'hired nazi constitutionally': True,
#    'one published argument': True,
#    'published argument hang': True,
#    'richard spencer would\\': True,
#    "spencer would\\ 've": True,
#    "would\\ 've hired": True,
#    "'ve hired": True,
#    'argument hang': True,
#    'hang richard': True,
#    'hired nazi': True,
#    'nazi constitutionally': True,
#    'one published': True,
#    'published argument': True,
#    'richard spencer': True,
#    'spencer would\\': True,
#    "would\\ 've": True,
#    'one': True,
#    'published': True,
#    'argument': True,
#    'hang': True,
#    'richard': True,
#    'spencer': True,
#    'would\\': True,
#    "'ve": True,
#    'hired': True,
#    'nazi': True,
#    'constitutionally': True},
#   'Bullying'),
#  ({'.if someone tell': True,
#    'asshole strongly consider': True,
#    'consider believing them..': True,
#    'someone tell strongest': True,
#    'strongest term asshole': True,
#    'strongly consider believing': True,
#    'tell strongest term': True,
#    'term asshole strongly': True,
#    '.if someone': True,
#    'asshole strongly': True,
#    'believing them..': True,
#    'consider believing': True,
#    'someone tell': True,
#    'strongest term': True,
#    'strongly consider': True,
#    'tell strongest': True,
#    'term asshole': True,
#    '.if': True,
#    'someone': True,
#    'tell': True,
#    'strongest': True,
#    'term': True,
#    'asshole': True,
#    'strongly': True,
#    'consider': True,
#    'believing': True,
#    'them..': True},
#   'Non-Bullying'),
#  ({'also stark reminder': True,
#    'auschwitz incredibly sobering': True,
#    'experience also stark': True,
#    'incredibly sobering experience': True,
#    'must continue oppo': True,
#    'reminder must continue': True,
#    'sobering experience also': True,
#    'stark reminder must': True,
#    'today visited auschwitz': True,
#    'visited auschwitz incredibly': True,
#    'also stark': True,
#    'auschwitz incredibly': True,
#    'continue oppo': True,
#    'experience also': True,
#    'incredibly sobering': True,
#    'must continue': True,
#    'reminder must': True,
#    'sobering experience': True,
#    'stark reminder': True,
#    'today visited': True,
#    'visited auschwitz': True,
#    'today': True,
#    'visited': True,
#    'auschwitz': True,
#    'incredibly': True,
#    'sobering': True,
#    'experience': True,
#    'also': True,
#    'stark': True,
#    'reminder': True,
#    'must': True,
#    'continue': True,
#    'oppo': True},
#   'Non-Bullying'),
#  ({'dumbass tried text': True,
#    'text bitch blocked': True,
#    'tried text bitch': True,
#    'bitch blocked': True,
#    'dumbass tried': True,
#    'text bitch': True,
#    'tried text': True,
#    'dumbass': True,
#    'tried': True,
#    'text': True,
#    'bitch': True,
#    'blocked': True},
#   'Non-Bullying'),
#  ({'idiot..': True}, 'Bullying'),
#  ({"'ve rented body": True,
#    'ann leary shook': True,
#    'april witch sure': True,
#    'body april witch': True,
#    "head i\\ 've": True,
#    "i\\ 've rented": True,
#    'leary shook head': True,
#    'rented body april': True,
#    'shook head i\\': True,
#    "close 'laughed cecy": True,
#    'witch sure close': True,
#    "close close 'laughed": True,
#    'sure close close': True,
#    "'laughed cecy": True,
#    "'ve rented": True,
#    'ann leary': True,
#    'april witch': True,
#    'body april': True,
#    'head i\\': True,
#    "i\\ 've": True,
#    'leary shook': True,
#    'rented body': True,
#    'shook head': True,
#    'witch sure': True,
#    "close 'laughed": True,
#    'sure close': True,
#    'close close': True,
#    'ann': True,
#    'leary': True,
#    'shook': True,
#    'head': True,
#    'i\\': True,
#    "'ve": True,
#    'rented': True,
#    'body': True,
#    'april': True,
#    'witch': True,
#    'sure': True,
#    'close': True,
#    "'laughed": True,
#    'cecy': True},
#   'Non-Bullying'),
#  ({"'people dumb thinking": True,
#    'dumb thinking it\\': True,
#    'it\\ act much': True,
#    "saying 'people dumb": True,
#    "thank saying 'people": True,
#    'thinking it\\ act': True,
#    "'people dumb": True,
#    'act much': True,
#    'dumb thinking': True,
#    'it\\ act': True,
#    "saying 'people": True,
#    'thank saying': True,
#    'thinking it\\': True,
#    'thank': True,
#    'saying': True,
#    "'people": True,
#    'dumb': True,
#    'thinking': True,
#    'it\\': True,
#    'act': True,
#    'much': True},
#   'Non-Bullying'),
#  ({'.whenever see photo': True,
#    'admission gulit fugly': True,
#    'filter take admission': True,
#    'girl wt snapchat': True,
#    'heart filter take': True,
#    'photo girl wt': True,
#    'see photo girl': True,
#    'snapchat heart filter': True,
#    'take admission gulit': True,
#    'wt snapchat heart': True,
#    '.whenever see': True,
#    'admission gulit': True,
#    'filter take': True,
#    'girl wt': True,
#    'gulit fugly': True,
#    'heart filter': True,
#    'photo girl': True,
#    'see photo': True,
#    'snapchat heart': True,
#    'take admission': True,
#    'wt snapchat': True,
#    '.whenever': True,
#    'see': True,
#    'photo': True,
#    'girl': True,
#    'wt': True,
#    'snapchat': True,
#    'heart': True,
#    'filter': True,
#    'take': True,
#    'admission': True,
#    'gulit': True,
#    'fugly': True},
#   'Non-Bullying'),
#  ({'..jakehighwell .keque.mage virtually': True,
#    '.keque.mage virtually every': True,
#    'called nazi l': True,
#    'decade called nazi': True,
#    'every republican running': True,
#    'office decade called': True,
#    'republican running office': True,
#    'running office decade': True,
#    'virtually every republican': True,
#    '..jakehighwell .keque.mage': True,
#    '.keque.mage virtually': True,
#    'called nazi': True,
#    'decade called': True,
#    'every republican': True,
#    'nazi l': True,
#    'office decade': True,
#    'republican running': True,
#    'running office': True,
#    'virtually every': True,
#    '..jakehighwell': True,
#    '.keque.mage': True,
#    'virtually': True,
#    'every': True,
#    'republican': True,
#    'running': True,
#    'office': True,
#    'decade': True,
#    'called': True,
#    'nazi': True,
#    'l': True},
#   'Non-Bullying'),
#  ({'.mind talking shit': True,
#    "championship 'his response": True,
#    'philadelphia winning championship': True,
#    'shit philadelphia winning': True,
#    'talking shit philadelphia': True,
#    "winning championship 'his": True,
#    "'his response": True,
#    '.mind talking': True,
#    "championship 'his": True,
#    'philadelphia winning': True,
#    'shit philadelphia': True,
#    'talking shit': True,
#    'winning championship': True,
#    '.mind': True,
#    'talking': True,
#    'shit': True,
#    'philadelphia': True,
#    'winning': True,
#    'championship': True,
#    "'his": True,
#    'response': True},
#   'Non-Bullying'),
#  ({'.my cute dumbass': True,
#    '.my cute': True,
#    'cute dumbass': True,
#    '.my': True,
#    'cute': True,
#    'dumbass': True},
#   'Non-Bullying'),
#  ({"'it bite everyone": True,
#    '.kamalaharris well time': True,
#    'bite everyone need': True,
#    'boycott show sponsor': True,
#    'everyone need held': True,
#    "show sponsor 'it": True,
#    "sponsor 'it bite": True,
#    'theellenshow .kamalaharris well': True,
#    'time boycott show': True,
#    'well time boycott': True,
#    "'it bite": True,
#    '.kamalaharris well': True,
#    'bite everyone': True,
#    'boycott show': True,
#    'everyone need': True,
#    'need held': True,
#    'show sponsor': True,
#    "sponsor 'it": True,
#    'theellenshow .kamalaharris': True,
#    'time boycott': True,
#    'well time': True,
#    'theellenshow': True,
#    '.kamalaharris': True,
#    'well': True,
#    'time': True,
#    'boycott': True,
#    'show': True,
#    'sponsor': True,
#    "'it": True,
#    'bite': True,
#    'everyone': True,
#    'need': True,
#    'held': True},
#   'Non-Bullying'),
#  ({"'without fact building": True,
#    '.because number low': True,
#    'building another fa': True,
#    'chap even country': True,
#    'country peddling trash': True,
#    'even country peddling': True,
#    'fact building another': True,
#    'iq chap even': True,
#    'low iq chap': True,
#    'number low iq': True,
#    "peddling trash 'without": True,
#    "trash 'without fact": True,
#    "'without fact": True,
#    '.because number': True,
#    'another fa': True,
#    'building another': True,
#    'chap even': True,
#    'country peddling': True,
#    'even country': True,
#    'fact building': True,
#    'iq chap': True,
#    'low iq': True,
#    'number low': True,
#    'peddling trash': True,
#    "trash 'without": True,
#    '.because': True,
#    'number': True,
#    'low': True,
#    'iq': True,
#    'chap': True,
#    'even': True,
#    'country': True,
#    'peddling': True,
#    'trash': True,
#    "'without": True,
#    'fact': True,
#    'building': True,
#    'another': True,
#    'fa': True},
#   'Bullying'),
#  ({'fugly po': True, 'fugly': True, 'po': True}, 'Bullying'),
#  ({'bts without prejudice': True,
#    'happens openly listen': True,
#    'listen bts without': True,
#    'openly listen bts': True,
#    'bts without': True,
#    'happens openly': True,
#    'listen bts': True,
#    'openly listen': True,
#    'without prejudice': True,
#    'happens': True,
#    'openly': True,
#    'listen': True,
#    'bts': True,
#    'without': True,
#    'prejudice': True},
#   'Non-Bullying'),
#  ({'.i bet scraping': True,
#    'bet scraping top': True,
#    'crooked thing dumbass': True,
#    'scraping top crooked': True,
#    'top crooked thing': True,
#    '.i bet': True,
#    'bet scraping': True,
#    'crooked thing': True,
#    'scraping top': True,
#    'thing dumbass': True,
#    'top crooked': True,
#    '.i': True,
#    'bet': True,
#    'scraping': True,
#    'top': True,
#    'crooked': True,
#    'thing': True,
#    'dumbass': True},
#   'Non-Bullying'),
#  ({"'hey kamala related": True,
#    ".kamalaharris loser 'hey": True,
#    'kamala related low': True,
#    "loser 'hey kamala": True,
#    'low iq maxine': True,
#    'related low iq': True,
#    "'hey kamala": True,
#    '.kamalaharris loser': True,
#    'iq maxine': True,
#    'kamala related': True,
#    "loser 'hey": True,
#    'low iq': True,
#    'related low': True,
#    '.kamalaharris': True,
#    'loser': True,
#    "'hey": True,
#    'kamala': True,
#    'related': True,
#    'low': True,
#    'iq': True,
#    'maxine': True},
#   'Bullying'),
#  ({'take white woman': True,
#    'white woman go': True,
#    'woman go nigger': True,
#    'go nigger': True,
#    'take white': True,
#    'white woman': True,
#    'woman go': True,
#    'take': True,
#    'white': True,
#    'woman': True,
#    'go': True,
#    'nigger': True},
#   'Bullying'),
#  ({'gangster pussy': True, 'gangster': True, 'pussy': True}, 'Bullying'),
#  ({'anything also know': True,
#    'deliberately misunderstand anything': True,
#    'misunderstand anything also': True,
#    'also know': True,
#    'anything also': True,
#    'deliberately misunderstand': True,
#    'misunderstand anything': True,
#    'deliberately': True,
#    'misunderstand': True,
#    'anything': True,
#    'also': True,
#    'know': True},
#   'Non-Bullying'),
#  ({"'dont shy away": True,
#    "'to white follower": True,
#    '.renireni writing vital': True,
#    "book 'dont shy": True,
#    'follower please read': True,
#    "piece work 'to": True,
#    'please read book': True,
#    "read book 'dont": True,
#    'shy away fro': True,
#    'thank .renireni writing': True,
#    'vital piece work': True,
#    'white follower please': True,
#    "work 'to white": True,
#    'writing vital piece': True,
#    "'dont shy": True,
#    "'to white": True,
#    '.renireni writing': True,
#    'away fro': True,
#    "book 'dont": True,
#    'follower please': True,
#    'piece work': True,
#    'please read': True,
#    'read book': True,
#    'shy away': True,
#    'thank .renireni': True,
#    'vital piece': True,
#    'white follower': True,
#    "work 'to": True,
#    'writing vital': True,
#    'thank': True,
#    '.renireni': True,
#    'writing': True,
#    'vital': True,
#    'piece': True,
#    'work': True,
#    "'to": True,
#    'white': True,
#    'follower': True,
#    'please': True,
#    'read': True,
#    'book': True,
#    "'dont": True,
#    'shy': True,
#    'away': True,
#    'fro': True},
#   'Non-Bullying'),
#  ({'closet fag know': True,
#    'diesel closet fag': True,
#    'fag know rock': True,
#    'know rock worried': True,
#    'made money one': True,
#    'money one yea': True,
#    'rock worried made': True,
#    'vin diesel closet': True,
#    'worried made money': True,
#    'closet fag': True,
#    'diesel closet': True,
#    'fag know': True,
#    'know rock': True,
#    'made money': True,
#    'money one': True,
#    'one yea': True,
#    'rock worried': True,
#    'vin diesel': True,
#    'worried made': True,
#    'vin': True,
#    'diesel': True,
#    'closet': True,
#    'fag': True,
#    'know': True,
#    'rock': True,
#    'worried': True,
#    'made': True,
#    'money': True,
#    'one': True,
#    'yea': True},
#   'Bullying'),
#  ({"'for love god": True,
#    "'please 'for love": True,
#    'care decade old': True,
#    'decade old story': True,
#    'god nobody care': True,
#    "got notification 'please": True,
#    'love god nobody': True,
#    'nobody care decade': True,
#    "notification 'please 'for": True,
#    'old story e': True,
#    "'for love": True,
#    "'please 'for": True,
#    'care decade': True,
#    'decade old': True,
#    'god nobody': True,
#    'got notification': True,
#    'love god': True,
#    'nobody care': True,
#    "notification 'please": True,
#    'old story': True,
#    'story e': True,
#    'got': True,
#    'notification': True,
#    "'please": True,
#    "'for": True,
#    'love': True,
#    'god': True,
#    'nobody': True,
#    'care': True,
#    'decade': True,
#    'old': True,
#    'story': True,
#    'e': True},
#   'Non-Bullying'),
#  ({'.bruuuuhh hope one': True,
#    'day dream pay': True,
#    'dream pay instead': True,
#    "fuck job 'bless": True,
#    'hope one day': True,
#    'instead working fuck': True,
#    "job 'bless man": True,
#    'one day dream': True,
#    'pay instead working': True,
#    'working fuck job': True,
#    "'bless man": True,
#    '.bruuuuhh hope': True,
#    'day dream': True,
#    'dream pay': True,
#    'fuck job': True,
#    'hope one': True,
#    'instead working': True,
#    "job 'bless": True,
#    'one day': True,
#    'pay instead': True,
#    'working fuck': True,
#    '.bruuuuhh': True,
#    'hope': True,
#    'one': True,
#    'day': True,
#    'dream': True,
#    'pay': True,
#    'instead': True,
#    'working': True,
#    'fuck': True,
#    'job': True,
#    "'bless": True,
#    'man': True},
#   'Non-Bullying'),
#  ({'fugly': True}, 'Non-Bullying'),
#  ({"'dumbass bit harsh": True,
#    "'inbred knuckle dragging": True,
#    "bit harsh 'inbred": True,
#    "call dimwit 'dumbass": True,
#    "dimwit 'dumbass bit": True,
#    'dragging mouth breather': True,
#    "harsh 'inbred knuckle": True,
#    'knuckle dragging mouth': True,
#    'mouth breather would': True,
#    'prefer call dimwit': True,
#    "'dumbass bit": True,
#    "'inbred knuckle": True,
#    'bit harsh': True,
#    'breather would': True,
#    'call dimwit': True,
#    "dimwit 'dumbass": True,
#    'dragging mouth': True,
#    "harsh 'inbred": True,
#    'knuckle dragging': True,
#    'mouth breather': True,
#    'prefer call': True,
#    'prefer': True,
#    'call': True,
#    'dimwit': True,
#    "'dumbass": True,
#    'bit': True,
#    'harsh': True,
#    "'inbred": True,
#    'knuckle': True,
#    'dragging': True,
#    'mouth': True,
#    'breather': True,
#    'would': True},
#   'Bullying'),
#  ({'lying piece shit': True,
#    'nothing worthless racist': True,
#    "piece shit 'you": True,
#    'racist lying piece': True,
#    'realdonaldtrump start trade': True,
#    "shit 'you shou": True,
#    'start trade war': True,
#    'trade war nothing': True,
#    'war nothing worthless': True,
#    'worthless racist lying': True,
#    "'you shou": True,
#    'lying piece': True,
#    'nothing worthless': True,
#    'piece shit': True,
#    'racist lying': True,
#    'realdonaldtrump start': True,
#    "shit 'you": True,
#    'start trade': True,
#    'trade war': True,
#    'war nothing': True,
#    'worthless racist': True,
#    'realdonaldtrump': True,
#    'start': True,
#    'trade': True,
#    'war': True,
#    'nothing': True,
#    'worthless': True,
#    'racist': True,
#    'lying': True,
#    'piece': True,
#    'shit': True,
#    "'you": True,
#    'shou': True},
#   'Bullying'),
#  ({'begging nobody attention..': True,
#    'attention fuck you..': True,
#    'attention.. fuck attention': True,
#    'nobody attention.. fuck': True,
#    'fuck attention fuck': True,
#    'begging nobody': True,
#    'nobody attention..': True,
#    'attention fuck': True,
#    'attention.. fuck': True,
#    'fuck attention': True,
#    'fuck you..': True,
#    'begging': True,
#    'nobody': True,
#    'attention..': True,
#    'fuck': True,
#    'attention': True,
#    'you..': True},
#   'Bullying'),
#  ({'gaining asshole': True, 'gaining': True, 'asshole': True}, 'Bullying'),
#  ({'feminism ting going': True,
#    'nah vat tag': True,
#    'tag team feminism': True,
#    'team feminism ting': True,
#    'vat tag team': True,
#    'feminism ting': True,
#    'nah vat': True,
#    'tag team': True,
#    'team feminism': True,
#    'ting going': True,
#    'vat tag': True,
#    'nah': True,
#    'vat': True,
#    'tag': True,
#    'team': True,
#    'feminism': True,
#    'ting': True,
#    'going': True},
#   'Non-Bullying'),
#  ({"'d aroace worried": True,
#    'aroace worried bc': True,
#    'bc someone us': True,
#    "id 'd aroace": True,
#    "still id 'd": True,
#    'thought still id': True,
#    'worried bc someone': True,
#    "'d aroace": True,
#    'aroace worried': True,
#    'bc someone': True,
#    "id 'd": True,
#    'someone us': True,
#    'still id': True,
#    'thought still': True,
#    'worried bc': True,
#    'thought': True,
#    'still': True,
#    'id': True,
#    "'d": True,
#    'aroace': True,
#    'worried': True,
#    'bc': True,
#    'someone': True,
#    'us': True},
#   'Non-Bullying'),
#  ({"'m sick democrat": True,
#    'as enough sat': True,
#    'become president ex': True,
#    'con-man become president': True,
#    "democrat didn\\'t kiss": True,
#    "didn\\'t kiss as": True,
#    'enough sat home': True,
#    'home let racist': True,
#    "i\\ 'm sick": True,
#    'kiss as enough': True,
#    'let racist nazi': True,
#    'nazi con-man become': True,
#    'racist nazi con-man': True,
#    'sat home let': True,
#    "sick democrat didn\\'t": True,
#    "'m sick": True,
#    'as enough': True,
#    'become president': True,
#    'con-man become': True,
#    "democrat didn\\'t": True,
#    "didn\\'t kiss": True,
#    'enough sat': True,
#    'home let': True,
#    "i\\ 'm": True,
#    'kiss as': True,
#    'let racist': True,
#    'nazi con-man': True,
#    'president ex': True,
#    'racist nazi': True,
#    'sat home': True,
#    'sick democrat': True,
#    'i\\': True,
#    "'m": True,
#    'sick': True,
#    'democrat': True,
#    "didn\\'t": True,
#    'kiss': True,
#    'as': True,
#    'enough': True,
#    'sat': True,
#    'home': True,
#    'let': True,
#    'racist': True,
#    'nazi': True,
#    'con-man': True,
#    'become': True,
#    'president': True,
#    'ex': True},
#   'Bullying'),
#  ({'atleast tweeting called': True,
#    'called fake news': True,
#    'fake news verified': True,
#    'low iq people': True,
#    'news verified handle': True,
#    'plus low iq': True,
#    'tweeting called fake': True,
#    'handle like plus': True,
#    'iq people like': True,
#    'like ca di': True,
#    'like plus low': True,
#    'people like ca': True,
#    'verified handle like': True,
#    'atleast tweeting': True,
#    'ca di': True,
#    'called fake': True,
#    'fake news': True,
#    'iq people': True,
#    'low iq': True,
#    'news verified': True,
#    'plus low': True,
#    'tweeting called': True,
#    'verified handle': True,
#    'handle like': True,
#    'like ca': True,
#    'like plus': True,
#    'people like': True,
#    'atleast': True,
#    'tweeting': True,
#    'called': True,
#    'fake': True,
#    'news': True,
#    'verified': True,
#    'handle': True,
#    'like': True,
#    'plus': True,
#    'low': True,
#    'iq': True,
#    'people': True,
#    'ca': True,
#    'di': True},
#   'Bullying'),
#  ({'.i bought cap': True,
#    'bought cap gown': True,
#    "cap gown 'yo": True,
#    "'yo really happening..": True,
#    'dumbass really graduating': True,
#    "gown 'yo really": True,
#    'happening.. dumbass really': True,
#    'really graduating college': True,
#    'really happening.. dumbass': True,
#    '.i bought': True,
#    'bought cap': True,
#    'cap gown': True,
#    "gown 'yo": True,
#    'graduating college': True,
#    'happening.. dumbass': True,
#    "'yo really": True,
#    'dumbass really': True,
#    'really graduating': True,
#    'really happening..': True,
#    '.i': True,
#    'bought': True,
#    'cap': True,
#    'gown': True,
#    "'yo": True,
#    'really': True,
#    'happening..': True,
#    'dumbass': True,
#    'graduating': True,
#    'college': True},
#   'Non-Bullying'),
#  ({'book shit lmaoooooooooo': True,
#    'excerpt book shit': True,
#    'female get relationship': True,
#    'get relationship sudden': True,
#    'lmaoooooooooo ohhhh n': True,
#    'posting excerpt book': True,
#    'relationship sudden start': True,
#    'shit lmaoooooooooo ohhhh': True,
#    'start posting excerpt': True,
#    'sudden start posting': True,
#    'book shit': True,
#    'excerpt book': True,
#    'female get': True,
#    'get relationship': True,
#    'lmaoooooooooo ohhhh': True,
#    'ohhhh n': True,
#    'posting excerpt': True,
#    'relationship sudden': True,
#    'shit lmaoooooooooo': True,
#    'start posting': True,
#    'sudden start': True,
#    'female': True,
#    'get': True,
#    'relationship': True,
#    'sudden': True,
#    'start': True,
#    'posting': True,
#    'excerpt': True,
#    'book': True,
#    'shit': True,
#    'lmaoooooooooo': True,
#    'ohhhh': True,
#    'n': True},
#   'Non-Bullying'),
#  ({'i. care prejudice': True,
#    'yes i. care': True,
#    'care prejudice': True,
#    'i. care': True,
#    'yes i.': True,
#    'yes': True,
#    'i.': True,
#    'care': True,
#    'prejudice': True},
#   'Non-Bullying'),
#  ({"'we qualify tournament": True,
#    "palpable 'we qualify": True,
#    "prejudice palpable 'we": True,
#    'qualify tournament c': True,
#    "'we qualify": True,
#    "palpable 'we": True,
#    'prejudice palpable': True,
#    'qualify tournament': True,
#    'tournament c': True,
#    'prejudice': True,
#    'palpable': True,
#    "'we": True,
#    'qualify': True,
#    'tournament': True,
#    'c': True},
#   'Non-Bullying'),
#  ({"'comparing u army": True,
#    'glorifying saddam shia': True,
#    'kurd living qasim': True,
#    'living qasim qadiani': True,
#    "qadiani 'comparing u": True,
#    "qasim qadiani 'comparing": True,
#    'saddam shia kurd': True,
#    'shia kurd living': True,
#    'u army wit': True,
#    'would glorifying saddam': True,
#    "'comparing u": True,
#    'army wit': True,
#    'glorifying saddam': True,
#    'kurd living': True,
#    'living qasim': True,
#    "qadiani 'comparing": True,
#    'qasim qadiani': True,
#    'saddam shia': True,
#    'shia kurd': True,
#    'u army': True,
#    'would glorifying': True,
#    'would': True,
#    'glorifying': True,
#    'saddam': True,
#    'shia': True,
#    'kurd': True,
#    'living': True,
#    'qasim': True,
#    'qadiani': True,
#    "'comparing": True,
#    'u': True,
#    'army': True,
#    'wit': True},
#   'Non-Bullying'),
#  ({'broke porkistan two': True,
#    'dp broke porkistan': True,
#    'man dp broke': True,
#    'porkistan two showed': True,
#    'broke porkistan': True,
#    'dp broke': True,
#    'man dp': True,
#    'porkistan two': True,
#    'two showed': True,
#    'man': True,
#    'dp': True,
#    'broke': True,
#    'porkistan': True,
#    'two': True,
#    'showed': True},
#   'Non-Bullying'),
#  ({'need retweets stop': True,
#    'retweets stop recycling': True,
#    'stuff praising feminism..': True,
#    'woke stuff praising': True,
#    'fake joke tweet': True,
#    'fake woke stuff': True,
#    'joke tweet fake': True,
#    'recycling fake joke': True,
#    'stop recycling fake': True,
#    'tweet fake woke': True,
#    'joke tweet': True,
#    'need retweets': True,
#    'praising feminism..': True,
#    'retweets stop': True,
#    'stop recycling': True,
#    'stuff praising': True,
#    'woke stuff': True,
#    'fake joke': True,
#    'fake woke': True,
#    'recycling fake': True,
#    'tweet fake': True,
#    'need': True,
#    'retweets': True,
#    'stop': True,
#    'recycling': True,
#    'fake': True,
#    'joke': True,
#    'tweet': True,
#    'woke': True,
#    'stuff': True,
#    'praising': True,
#    'feminism..': True},
#   'Non-Bullying'),
#  ({'group thug mentality': True,
#    'whole group thug': True,
#    'make pussy care': True,
#    'mentality make tough': True,
#    'thug mentality make': True,
#    'tough make pussy': True,
#    'make tough make': True,
#    'group thug': True,
#    'pussy care': True,
#    'thug mentality': True,
#    'whole group': True,
#    'make pussy': True,
#    'make tough': True,
#    'mentality make': True,
#    'tough make': True,
#    'whole': True,
#    'group': True,
#    'thug': True,
#    'mentality': True,
#    'make': True,
#    'tough': True,
#    'pussy': True,
#    'care': True},
#   'Bullying'),
#  ({"affect 'you talking": True,
#    'america care real': True,
#    'care real news': True,
#    'damn twit america': True,
#    'give damn twit': True,
#    "news affect 'you": True,
#    'nobody give damn': True,
#    'real news affect': True,
#    'twit america care': True,
#    "'you talking": True,
#    "affect 'you": True,
#    'america care': True,
#    'care real': True,
#    'damn twit': True,
#    'give damn': True,
#    'news affect': True,
#    'nobody give': True,
#    'real news': True,
#    'twit america': True,
#    'nobody': True,
#    'give': True,
#    'damn': True,
#    'twit': True,
#    'america': True,
#    'care': True,
#    'real': True,
#    'news': True,
#    'affect': True,
#    "'you": True,
#    'talking': True},
#   'Bullying'),
#  ({'.gaepol sir asshole': True,
#    'davidhogg111 .gaepol sir': True,
#    '.gaepol sir': True,
#    'davidhogg111 .gaepol': True,
#    'sir asshole': True,
#    'davidhogg111': True,
#    '.gaepol': True,
#    'sir': True,
#    'asshole': True},
#   'Bullying'),
#  ({'close hilarious funny': True,
#    'funny sick stuff': True,
#    'hilarious funny sick': True,
#    'honestly nothing close': True,
#    'nothing close hilarious': True,
#    'close hilarious': True,
#    'funny sick': True,
#    'hilarious funny': True,
#    'honestly nothing': True,
#    'nothing close': True,
#    'sick stuff': True,
#    'honestly': True,
#    'nothing': True,
#    'close': True,
#    'hilarious': True,
#    'funny': True,
#    'sick': True,
#    'stuff': True},
#   'Non-Bullying'),
#  ({'fucking worthless piece': True,
#    'piece shit .realdonaldtrump': True,
#    'shit .realdonaldtrump diealready': True,
#    'word fucking worthless': True,
#    'worthless piece shit': True,
#    '.realdonaldtrump diealready': True,
#    'fucking worthless': True,
#    'piece shit': True,
#    'shit .realdonaldtrump': True,
#    'word fucking': True,
#    'worthless piece': True,
#    'word': True,
#    'fucking': True,
#    'worthless': True,
#    'piece': True,
#    'shit': True,
#    '.realdonaldtrump': True,
#    'diealready': True},
#   'Bullying'),
#  ({'god pussy pick': True,
#    'oh god pussy': True,
#    'pick current archaeolo': True,
#    'pussy pick current': True,
#    'realjameswoods oh god': True,
#    'current archaeolo': True,
#    'god pussy': True,
#    'oh god': True,
#    'pick current': True,
#    'pussy pick': True,
#    'realjameswoods oh': True,
#    'realjameswoods': True,
#    'oh': True,
#    'god': True,
#    'pussy': True,
#    'pick': True,
#    'current': True,
#    'archaeolo': True},
#   'Bullying'),
#  ({'dumbass one word..': True,
#    'dumbass one': True,
#    'one word..': True,
#    'dumbass': True,
#    'one': True,
#    'word..': True},
#   'Non-Bullying'),
#  ({'.jimmykimmel forget speaks': True,
#    '5 language many': True,
#    'forget speaks 5': True,
#    'language many speak': True,
#    'many speak maybe': True,
#    'maybe spanish low': True,
#    'spanish low iq': True,
#    'speak maybe spanish': True,
#    'speaks 5 language': True,
#    '.jimmykimmel forget': True,
#    '5 language': True,
#    'forget speaks': True,
#    'language many': True,
#    'low iq': True,
#    'many speak': True,
#    'maybe spanish': True,
#    'spanish low': True,
#    'speak maybe': True,
#    'speaks 5': True,
#    '.jimmykimmel': True,
#    'forget': True,
#    'speaks': True,
#    '5': True,
#    'language': True,
#    'many': True,
#    'speak': True,
#    'maybe': True,
#    'spanish': True,
#    'low': True,
#    'iq': True},
#   'Bullying'),
#  ({'assault rifle need': True,
#    'getting violently murdered': True,
#    'kid know u': True,
#    'know u want': True,
#    'listen kid know': True,
#    'murdered assault rifle': True,
#    'need grow realize': True,
#    'rifle need grow': True,
#    'stop getting violently': True,
#    'u want stop': True,
#    'violently murdered assault': True,
#    'want stop getting': True,
#    'assault rifle': True,
#    'getting violently': True,
#    'grow realize': True,
#    'kid know': True,
#    'know u': True,
#    'listen kid': True,
#    'murdered assault': True,
#    'need grow': True,
#    'rifle need': True,
#    'stop getting': True,
#    'u want': True,
#    'violently murdered': True,
#    'want stop': True,
#    'listen': True,
#    'kid': True,
#    'know': True,
#    'u': True,
#    'want': True,
#    'stop': True,
#    'getting': True,
#    'violently': True,
#    'murdered': True,
#    'assault': True,
#    'rifle': True,
#    'need': True,
#    'grow': True,
#    'realize': True},
#   'Non-Bullying'),
#  ({'acknowledged erdogan goatfucker..': True,
#    'widely acknowledged erdogan': True,
#    'acknowledged erdogan': True,
#    'erdogan goatfucker..': True,
#    'widely acknowledged': True,
#    'widely': True,
#    'acknowledged': True,
#    'erdogan': True,
#    'goatfucker..': True},
#   'Non-Bullying'),
#  ({'bye libtard sorry': True,
#    'finish work massage': True,
#    'libtard sorry low': True,
#    'like finish work': True,
#    'massage parlor bye': True,
#    'meant smell like': True,
#    'parlor bye libtard': True,
#    'smell like finish': True,
#    'sorry low iq..': True,
#    'work massage parlor': True,
#    'bye libtard': True,
#    'finish work': True,
#    'libtard sorry': True,
#    'like finish': True,
#    'low iq..': True,
#    'massage parlor': True,
#    'meant smell': True,
#    'parlor bye': True,
#    'smell like': True,
#    'sorry low': True,
#    'work massage': True,
#    'meant': True,
#    'smell': True,
#    'like': True,
#    'finish': True,
#    'work': True,
#    'massage': True,
#    'parlor': True,
#    'bye': True,
#    'libtard': True,
#    'sorry': True,
#    'low': True,
#    'iq..': True},
#   'Bullying'),
#  ({'awkward moment street': True,
#    'moment street world': True,
#    'notice people around': True,
#    'street world talking': True,
#    'talking notice people': True,
#    'world talking notice': True,
#    'awkward moment': True,
#    'moment street': True,
#    'notice people': True,
#    'people around': True,
#    'street world': True,
#    'talking notice': True,
#    'world talking': True,
#    'awkward': True,
#    'moment': True,
#    'street': True,
#    'world': True,
#    'talking': True,
#    'notice': True,
#    'people': True,
#    'around': True},
#   'Non-Bullying'),
#  ({'allow god given': True,
#    'constitution taken idiot': True,
#    'dependent constitution taken': True,
#    'given right dependent': True,
#    'god given right': True,
#    'right dependent constitution': True,
#    'allow god': True,
#    'constitution taken': True,
#    'dependent constitution': True,
#    'given right': True,
#    'god given': True,
#    'right dependent': True,
#    'taken idiot': True,
#    'allow': True,
#    'god': True,
#    'given': True,
#    'right': True,
#    'dependent': True,
#    'constitution': True,
#    'taken': True,
#    'idiot': True},
#   'Bullying'),
#  ({'1 guy shit': True,
#    'around v 1': True,
#    'come hide like': True,
#    'fucking pussy tough': True,
#    'got team around': True,
#    'guy shit come': True,
#    'hide like little': True,
#    'like little bitch': True,
#    'pussy tough got': True,
#    'shit come hide': True,
#    'team around v': True,
#    'tough got team': True,
#    'v 1 guy': True,
#    '1 guy': True,
#    'around v': True,
#    'come hide': True,
#    'fucking pussy': True,
#    'got team': True,
#    'guy shit': True,
#    'hide like': True,
#    'like little': True,
#    'little bitch': True,
#    'pussy tough': True,
#    'shit come': True,
#    'team around': True,
#    'tough got': True,
#    'v 1': True,
#    'fucking': True,
#    'pussy': True,
#    'tough': True,
#    'got': True,
#    'team': True,
#    'around': True,
#    'v': True,
#    '1': True,
#    'guy': True,
#    'shit': True,
#    'come': True,
# ...
#    'retard yes correct': True,
#    'savage mean fucking': True,
#    'fucking retard': True,
#    'mean fucking': True,
#    'retard yes': True,
#    'savage mean': True,
#    'yes correct': True,
#    'savage': True,
#    'mean': True,
#    'fucking': True,
#    'retard': True,
#    'yes': True,
#    'correct': True},
#   'Non-Bullying'),
#  ({'bitch fugly smoking': True,
#    'dope like junky': True,
#    'fugly smoking dope': True,
#    'like junky \\u0001f92a': True,
#    'smoking dope like': True,
#    'bitch fugly': True,
#    'dope like': True,
#    'fugly smoking': True,
#    'junky \\u0001f92a': True,
#    'like junky': True,
#    'smoking dope': True,
#    'bitch': True,
#    'fugly': True,
#    'smoking': True,
#    'dope': True,
#    'like': True,
#    'junky': True,
#    '\\u0001f92a': True},
#   'Bullying'),
#  ({"dubai '- 10": True,
#    "'- 10": True,
#    "dubai '-": True,
#    'dubai': True,
#    "'-": True,
#    '10': True},
#   'Non-Bullying'),
#  ({'2018 dumbass aw': True,
#    'everyone 2018 dumbass': True,
#    'wtf everyone 2018': True,
#    'ya wtf everyone': True,
#    '2018 dumbass': True,
#    'dumbass aw': True,
#    'everyone 2018': True,
#    'wtf everyone': True,
#    'ya wtf': True,
#    'ya': True,
#    'wtf': True,
#    'everyone': True,
#    '2018': True,
#    'dumbass': True,
#    'aw': True},
#   'Bullying'),
#  ({"'ayo fayose chief": True,
#    "'is corrupt failed": True,
#    "'obasanjo tell govt": True,
#    "agree gov 'ayo": True,
#    'corrupt failed agree': True,
#    'failed agree gov': True,
#    'fayose chief f': True,
#    "gov 'ayo fayose": True,
#    "govt 'is corrupt": True,
#    "pres 'obasanjo tell": True,
#    "tell govt 'is": True,
#    "'ayo fayose": True,
#    "'is corrupt": True,
#    "'obasanjo tell": True,
#    'agree gov': True,
#    'chief f': True,
#    'corrupt failed': True,
#    'failed agree': True,
#    'fayose chief': True,
#    "gov 'ayo": True,
#    "govt 'is": True,
#    "pres 'obasanjo": True,
#    'tell govt': True,
#    'pres': True,
#    "'obasanjo": True,
#    'tell': True,
#    'govt': True,
#    "'is": True,
#    'corrupt': True,
#    'failed': True,
#    'agree': True,
#    'gov': True,
#    "'ayo": True,
#    'fayose': True,
#    'chief': True,
#    'f': True},
#   'Non-Bullying'),
#  ({"'bc letter end": True,
#    "'like imagine thinking": True,
#    "'straight ppl next": True,
#    "*beside 'like imagine": True,
#    "acceptable 'bc letter": True,
#    "end 'straight ppl": True,
#    'gon na saying': True,
#    'imagine thinking acceptable': True,
#    "letter end 'straight": True,
#    'na saying well': True,
#    'next week gon': True,
#    'ppl next week': True,
#    "thinking acceptable 'bc": True,
#    'week gon na': True,
#    "'bc letter": True,
#    "'like imagine": True,
#    "'straight ppl": True,
#    "*beside 'like": True,
#    "acceptable 'bc": True,
#    "end 'straight": True,
#    'gon na': True,
#    'imagine thinking': True,
#    'letter end': True,
#    'na saying': True,
#    'next week': True,
#    'ppl next': True,
#    'saying well': True,
#    'thinking acceptable': True,
#    'week gon': True,
#    '*beside': True,
#    "'like": True,
#    'imagine': True,
#    'thinking': True,
#    'acceptable': True,
#    "'bc": True,
#    'letter': True,
#    'end': True,
#    "'straight": True,
#    'ppl': True,
#    'next': True,
#    'week': True,
#    'gon': True,
#    'na': True,
#    'saying': True,
#    'well': True},
#   'Non-Bullying'),
#  ({'another nasty piece': True,
#    'asshole blown apart': True,
#    'fucking asshole blown': True,
#    'nasty piece shit': True,
#    'piece shit cunt': True,
#    'getting fucking asshole': True,
#    'shit cunt getting': True,
#    'cunt getting getting': True,
#    'getting getting fucking': True,
#    'another nasty': True,
#    'asshole blown': True,
#    'blown apart': True,
#    'fucking asshole': True,
#    'nasty piece': True,
#    'piece shit': True,
#    'shit cunt': True,
#    'cunt getting': True,
#    'getting fucking': True,
#    'getting getting': True,
#    'another': True,
#    'nasty': True,
#    'piece': True,
#    'shit': True,
#    'cunt': True,
#    'getting': True,
#    'fucking': True,
#    'asshole': True,
#    'blown': True,
#    'apart': True},
#   'Bullying'),
#  ({'asshole like ruining': True,
#    'country. instead helping': True,
#    'fuck lady libtard': True,
#    'helping secure board': True,
#    'instead helping secure': True,
#    'lady libtard asshole': True,
#    'libtard asshole like': True,
#    'like ruining country.': True,
#    'ruining country. instead': True,
#    'asshole like': True,
#    'country. instead': True,
#    'fuck lady': True,
#    'helping secure': True,
#    'instead helping': True,
#    'lady libtard': True,
#    'libtard asshole': True,
#    'like ruining': True,
#    'ruining country.': True,
#    'secure board': True,
#    'fuck': True,
#    'lady': True,
#    'libtard': True,
#    'asshole': True,
#    'like': True,
#    'ruining': True,
#    'country.': True,
#    'instead': True,
#    'helping': True,
#    'secure': True,
#    'board': True},
#   'Bullying'),
#  ({"best player 'play": True,
#    'excuse literally fact': True,
#    'fact best player': True,
#    'injury excuse literally': True,
#    'literally fact best': True,
#    "player 'play u": True,
#    "'play u": True,
#    'best player': True,
#    'excuse literally': True,
#    'fact best': True,
#    'injury excuse': True,
#    'literally fact': True,
#    "player 'play": True,
#    'injury': True,
#    'excuse': True,
#    'literally': True,
#    'fact': True,
#    'best': True,
#    'player': True,
#    "'play": True,
#    'u': True},
#   'Non-Bullying'),
#  ({'nigger': True}, 'Bullying'),
#  ({'calling fight every': True,
#    'every type prejudice': True,
#    'fight every type': True,
#    'jew particular calling': True,
#    'particular calling fight': True,
#    'prejudice support muslim': True,
#    'support muslim brother': True,
#    'type prejudice support': True,
#    'calling fight': True,
#    'every type': True,
#    'fight every': True,
#    'jew particular': True,
#    'muslim brother': True,
#    'particular calling': True,
#    'prejudice support': True,
#    'support muslim': True,
#    'type prejudice': True,
#    'jew': True,
#    'particular': True,
#    'calling': True,
#    'fight': True,
#    'every': True,
#    'type': True,
#    'prejudice': True,
#    'support': True,
#    'muslim': True,
#    'brother': True},
#   'Non-Bullying'),
#  ({"'like bitch know": True,
#    "'trying amp begging": True,
#    'amp begging comple': True,
#    "as mf 'like": True,
#    'beg life as': True,
#    'bitch know effort': True,
#    "effort 'trying amp": True,
#    'hate beg life': True,
#    "know effort 'trying": True,
#    'life as mf': True,
#    "mf 'like bitch": True,
#    "'like bitch": True,
#    "'trying amp": True,
#    'amp begging': True,
#    'as mf': True,
#    'beg life': True,
#    'begging comple': True,
#    'bitch know': True,
#    "effort 'trying": True,
#    'hate beg': True,
#    'know effort': True,
#    'life as': True,
#    "mf 'like": True,
#    'hate': True,
#    'beg': True,
#    'life': True,
#    'as': True,
#    'mf': True,
#    "'like": True,
#    'bitch': True,
#    'know': True,
#    'effort': True,
#    "'trying": True,
#    'amp': True,
#    'begging': True,
#    'comple': True},
#   'Non-Bullying'),
#  ({'amp self entitlement': True,
#    'complex amp self': True,
#    'entitlement issue mainly': True,
#    'inferiority complex amp': True,
#    'iq inferiority complex': True,
#    'low iq inferiority': True,
#    'self entitlement issue': True,
#    'amp self': True,
#    'complex amp': True,
#    'entitlement issue': True,
#    'inferiority complex': True,
#    'iq inferiority': True,
#    'issue mainly': True,
#    'low iq': True,
#    'self entitlement': True,
#    'low': True,
#    'iq': True,
#    'inferiority': True,
#    'complex': True,
#    'amp': True,
#    'self': True,
#    'entitlement': True,
#    'issue': True,
#    'mainly': True},
#   'Bullying'),
#  ({'eat shit die': True,
#    'goatfucker eat shit': True,
#    'eat shit': True,
#    'goatfucker eat': True,
#    'shit die': True,
#    'goatfucker': True,
#    'eat': True,
#    'shit': True,
#    'die': True},
#   'Bullying'),
#  ({'america worthless human': True,
#    'anyone make coward': True,
#    'death anyone make': True,
#    'human wishing death': True,
#    'leave america worthless': True,
#    'piece shit leave': True,
#    'shit leave america': True,
#    'wishing death anyone': True,
#    'worthless human wishing': True,
#    'america worthless': True,
#    'anyone make': True,
#    'death anyone': True,
#    'human wishing': True,
#    'leave america': True,
#    'make coward': True,
#    'piece shit': True,
#    'shit leave': True,
#    'wishing death': True,
#    'worthless human': True,
#    'piece': True,
#    'shit': True,
#    'leave': True,
#    'america': True,
#    'worthless': True,
#    'human': True,
#    'wishing': True,
#    'death': True,
#    'anyone': True,
#    'make': True,
#    'coward': True},
#   'Bullying'),
#  ({'jerkoff are. libtard..': True,
#    'jimmykimmel figure asshole': True,
#    'mr trump. jerkoff': True,
#    'trump. jerkoff are.': True,
#    'would insult woman': True,
#    'asshole like would': True,
#    'figure asshole like': True,
#    'insult woman like': True,
#    'like mr trump.': True,
#    'like would insult': True,
#    'woman like mr': True,
#    'are. libtard..': True,
#    'figure asshole': True,
#    'insult woman': True,
#    'jerkoff are.': True,
#    'jimmykimmel figure': True,
#    'mr trump.': True,
#    'trump. jerkoff': True,
#    'would insult': True,
#    'asshole like': True,
#    'like mr': True,
#    'like would': True,
#    'woman like': True,
#    'jimmykimmel': True,
#    'figure': True,
#    'asshole': True,
#    'like': True,
#    'would': True,
#    'insult': True,
#    'woman': True,
#    'mr': True,
#    'trump.': True,
#    'jerkoff': True,
#    'are.': True,
#    'libtard..': True},
#   'Bullying'),
#  ({'get mention goatfucker..': True,
#    'get mention': True,
#    'mention goatfucker..': True,
#    'get': True,
#    'mention': True,
#    'goatfucker..': True},
#   'Bullying'),
#  ({'fugly pelican': True, 'fugly': True, 'pelican': True}, 'Bullying'),
#  ({'attribute miserable fugly': True,
#    'bitter demented bitch': True,
#    'demented bitch way': True,
#    'fugly bitter demented': True,
#    'miserable fugly bitter': True,
#    'r tuing ur': True,
#    'tuing ur bf': True,
#    'ur bf oops': True,
#    'bf oops u': True,
#    'bitch way u': True,
#    'u r tuing': True,
#    'way u r': True,
#    'attribute miserable': True,
#    'bf oops': True,
#    'bitch way': True,
#    'bitter demented': True,
#    'demented bitch': True,
#    'fugly bitter': True,
#    'miserable fugly': True,
#    'r tuing': True,
#    'tuing ur': True,
#    'ur bf': True,
#    'oops u': True,
#    'u r': True,
#    'way u': True,
#    'attribute': True,
#    'miserable': True,
#    'fugly': True,
#    'bitter': True,
#    'demented': True,
#    'bitch': True,
#    'way': True,
#    'u': True,
#    'r': True,
#    'tuing': True,
#    'ur': True,
#    'bf': True,
#    'oops': True},
#   'Bullying'),
#  ({'ky faggot': True, 'ky': True, 'faggot': True}, 'Bullying'),
#  ({'nobody care whore': True,
#    'care whore': True,
#    'nobody care': True,
#    'nobody': True,
#    'care': True,
#    'whore': True},
#   'Bullying'),
#  ({'inherently dangerous ci': True,
#    'make inherently dangerous': True,
#    "ci woman 'th": True,
#    'dangerous ci woman': True,
#    'trans woman make': True,
#    'woman make inherently': True,
#    'dangerous ci': True,
#    'inherently dangerous': True,
#    'make inherently': True,
#    'ci woman': True,
#    'trans woman': True,
#    "woman 'th": True,
#    'woman make': True,
#    'trans': True,
#    'woman': True,
#    'make': True,
#    'inherently': True,
#    'dangerous': True,
#    'ci': True,
#    "'th": True},
#   'Non-Bullying'),
#  ({'.record beat nigger': True,
#    '.record beat': True,
#    'beat nigger': True,
#    '.record': True,
#    'beat': True,
#    'nigger': True},
#   'Non-Bullying'),
#  ({"'gaming atheism feminism": True,
#    "'go forth argue": True,
#    "argue internet 'gaming": True,
#    'atheism feminism anime': True,
#    "baptized 'go forth": True,
#    'feminism anime domain..': True,
#    'forth argue internet': True,
#    'good sir baptized': True,
#    "internet 'gaming atheism": True,
#    "sir baptized 'go": True,
#    "'gaming atheism": True,
#    "'go forth": True,
#    'anime domain..': True,
#    'argue internet': True,
#    'atheism feminism': True,
#    "baptized 'go": True,
#    'feminism anime': True,
#    'forth argue': True,
#    'good sir': True,
#    "internet 'gaming": True,
#    'sir baptized': True,
#    'good': True,
#    'sir': True,
#    'baptized': True,
#    "'go": True,
#    'forth': True,
#    'argue': True,
#    'internet': True,
#    "'gaming": True,
#    'atheism': True,
#    'feminism': True,
#    'anime': True,
#    'domain..': True},
#   'Non-Bullying'),
#  ({'fag': True}, 'Bullying'),
#  ({'attempt salvaging elsction': True,
#    'elsction hope anything': True,
#    'hope anything else': True,
#    'salvaging elsction hope': True,
#    'spin attempt salvaging': True,
#    'anything else': True,
#    'attempt salvaging': True,
#    'elsction hope': True,
#    'hope anything': True,
#    'salvaging elsction': True,
#    'spin attempt': True,
#    'spin': True,
#    'attempt': True,
#    'salvaging': True,
#    'elsction': True,
#    'hope': True,
#    'anything': True,
#    'else': True},
#   'Non-Bullying'),
#  ({"'m fake anything": True,
#    'anything keep pretending': True,
#    'fake anything keep': True,
#    "'m fake": True,
#    'anything keep': True,
#    'fake anything': True,
#    'keep pretending': True,
#    "'m": True,
#    'fake': True,
#    'anything': True,
#    'keep': True,
#    'pretending': True},
#   'Non-Bullying'),
#  ({'idiot..': True}, 'Bullying'),
#  ({"'well stop going": True,
#    'girl saying men': True,
#    'going guy wan': True,
#    'guy wan na': True,
#    'men trash shit': True,
#    'saying men trash': True,
#    "shit 'well stop": True,
#    'stop going guy': True,
#    "trash shit 'well": True,
#    'wan na f': True,
#    "'well stop": True,
#    'girl saying': True,
#    'going guy': True,
#    'guy wan': True,
#    'men trash': True,
#    'na f': True,
#    'saying men': True,
#    "shit 'well": True,
#    'stop going': True,
#    'trash shit': True,
#    'wan na': True,
#    'girl': True,
#    'saying': True,
#    'men': True,
#    'trash': True,
#    'shit': True,
#    "'well": True,
#    'stop': True,
#    'going': True,
#    'guy': True,
#    'wan': True,
#    'na': True,
#    'f': True},
#   'Non-Bullying'),
#  ({'deems worthy coverage': True,
#    'iq medium deems': True,
#    'low iq medium': True,
#    'medium deems worthy': True,
#    'oh really low': True,
#    'really low iq': True,
#    'deems worthy': True,
#    'iq medium': True,
#    'low iq': True,
#    'medium deems': True,
#    'oh really': True,
#    'really low': True,
#    'worthy coverage': True,
#    'oh': True,
#    'really': True,
#    'low': True,
#    'iq': True,
#    'medium': True,
#    'deems': True,
#    'worthy': True,
#    'coverage': True},
#   'Bullying'),
#  ({"'all saying tweet": True,
#    "'if ya dumbass": True,
#    'defending white people': True,
#    "hypocrite 'if ya": True,
#    "people 'all saying": True,
#    'saying tweet hypocrite': True,
#    "tweet hypocrite 'if": True,
#    "white people 'all": True,
#    'ya dumbass would': True,
#    "'all saying": True,
#    "'if ya": True,
#    'defending white': True,
#    'dumbass would': True,
#    "hypocrite 'if": True,
#    "people 'all": True,
#    'saying tweet': True,
#    'tweet hypocrite': True,
#    'white people': True,
#    'ya dumbass': True,
#    'defending': True,
#    'white': True,
#    'people': True,
#    "'all": True,
#    'saying': True,
#    'tweet': True,
#    'hypocrite': True,
#    "'if": True,
#    'ya': True,
#    'dumbass': True,
#    'would': True},
#   'Non-Bullying'),
#  ({'fag break girl': True,
#    "got see '.brightond": True,
#    'break girl got': True,
#    'girl got see': True,
#    'girl got girl': True,
#    'got girl got': True,
#    'fag break': True,
#    'girl got': True,
#    "see '.brightond": True,
#    'break girl': True,
#    'got see': True,
#    'got girl': True,
#    'fag': True,
#    'break': True,
#    'girl': True,
#    'got': True,
#    'see': True,
#    "'.brightond": True},
#   'Non-Bullying'),
#  ({'alone suggest u': True,
#    'suggest u leave': True,
#    'u leave spoofers': True,
#    'fuck leave alone': True,
#    'leave alone suggest': True,
#    'leave spoofers alone': True,
#    'suggest u': True,
#    'alone suggest': True,
#    'fuck leave': True,
#    'leave spoofers': True,
#    'spoofers alone': True,
#    'u leave': True,
#    'leave alone': True,
#    'fuck': True,
#    'leave': True,
#    'alone': True,
#    'suggest': True,
#    'u': True,
#    'spoofers': True},
#   'Non-Bullying')]

# %%
dt_classifier = DecisionTreeClassifier.train(train_set, 
                                             binary=True, 
                                             entropy_cutoff=0.8, 
                                             depth_cutoff=5, 
                                             support_cutoff=30)

# %%
refset = collections.defaultdict(set)
testset = collections.defaultdict(set)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = dt_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("Decision Tree Performance with Ngrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# Decision Tree Performance with Ngrams
# Accuracy: 0.6037735849056604

# %%
logit_classifier = MaxentClassifier.train(train_set, algorithm='gis', trace=0, max_iter=10, min_lldelta=0.5)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = logit_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("Maxent Performance with Ngrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# Maxent Performance with Ngrams
# Accuracy: 0.6037735849056604

# %%
SVM_classifier = SklearnClassifier(SVC(), sparse=False).train(train_set)

# %%
for i, (feats, label) in enumerate(test_set):
    refset[label].add(i)
    observed = SVM_classifier.classify(feats)
    testset[observed].add(i)

# %%
print("SVM Performance with Ngrams ")    
print("Accuracy:",nltk.classify.accuracy(classifier, test_set))
# Out:
# SVM Performance with Ngrams
# Accuracy: 0.6037735849056604

# %%
train_set, test_set = Final_Data[0:747], Final_Data[747:]

# %%
test_set
# Out:
# [({"'m": True, 'fed': True, 'migraine': True}, 'Non-Bullying'),
#  ({'.sorry': True,
#    'runner': True,
#    'popular': True,
#    'right': True,
#    'plain': True,
#    'fugly': True},
#   'Non-Bullying'),
#  ({'lol': True,
#    'low': True,
#    'iq': True,
#    'moron': True,
#    'running': True,
#    'mouth': True,
#    "'probably": True,
#    'comment': True,
#    'demonstrates': True,
#    'wishful': True,
#    'thinking': True,
#    'butt': True},
#   'Bullying'),
#  ({'stage': True,
#    'realising': True,
#    'accepting': True,
#    'white': True,
#    'inferior': True,
#    'fag': True,
#    'mistress': True,
#    'invite': True,
#    'sir': True,
#    'mate': True,
#    'yo': True},
#   'Bullying'),
#  ({'ai': True,
#    'bro': True,
#    'swear': True,
#    '.g00dgirlsteph': True,
#    'got': True,
#    'ta': True,
#    'watch': True,
#    "'she": True,
#    'found': True,
#    'grandpa': True,
#    'f': True},
#   'Non-Bullying'),
#  ({'.record': True, 'beat': True, 'nigger': True}, 'Non-Bullying'),
#  ({'ooh': True, 'please': True, 'totally': True, 'fine': True, 'pussy': True},
#   'Bullying'),
#  ({'ya': True,
#    'wtf': True,
#    'everyone': True,
#    '2018': True,
#    'dumbass': True,
#    'aw': True},
#   'Bullying'),
#  ({"'ve": True,
#    'reread': True,
#    'thread': True,
#    'began': True,
#    'hope': True,
#    'come': True,
#    'understand': True,
#    'dis': True},
#   'Non-Bullying'),
#  ({'bluemanc71': True,
#    'said': True,
#    'hanzo': True,
#    'genji': True,
#    "'m": True,
#    'weebo': True},
#   'Non-Bullying'),
#  ({'.poor': True,
#    'dog..nothing': True,
#    'good': True,
#    'come': True,
#    'arab..goatfucker': True},
#   'Bullying'),
#  ({'dumb': True,
#    'nigger': True,
#    "'you": True,
#    'chance': True,
#    'something': True,
#    'osama': True,
#    'obama': True,
#    'president': True},
#   'Bullying'),
#  ({'big': True,
#    'white': True,
#    'booty': True,
#    'deserves': True,
#    'black': True,
#    'cock': True,
#    'getting': True,
#    'slut': True,
#    'throw': True,
#    'fat': True,
#    'arse': True,
#    'back': True,
#    'daddy': True},
#   'Bullying'),
#  ({'cassie': True,
#    "'everyone": True,
#    'else': True,
#    'fugly': True,
#    'dumb..': True},
#   'Non-Bullying'),
#  ({'.go': True,
#    'fuck': True,
#    'bloody': True,
#    'porki': True,
#    'goatfucker': True,
#    "'is": True,
#    'bar': True,
#    'bhi': True,
#    'i.p.l': True,
#    'e': True,
#    'khelne': True,
#    'nahi': True,
#    'doa': True,
#    'hska': True,
#    'gussa': True,
#    'hai': True,
#    'kya': True,
#    "'chutiya": True,
#    'sal': True},
#   'Bullying'),
#  ({'nobody': True, 'care': True, 'whore': True}, 'Bullying'),
#  ({'phil': True,
#    'say': True,
#    'goatfuckers': True,
#    'international': True,
#    '12:32': True,
#    'knowing': True,
#    'derogatory': True,
#    'term': True,
#    'used': True,
#    'towa': True},
#   'Non-Bullying'),
#  ({'.what': True,
#    'stupid': True,
#    'cunt': True,
#    'designed': True,
#    'obby': True,
#    'get': True,
#    'fifteam': True,
#    'egg': True,
#    "'too.fucking.difficult": True,
#    "'omg": True},
#   'Non-Bullying'),
#  ({'.i': True,
#    'control': True,
#    'mother': True,
#    "'she": True,
#    'really': True,
#    'said': True,
#    'spell': True,
#    'nigga': True,
#    'n-i-g-g-a': True,
#    'go': True,
#    'wh': True},
#   'Non-Bullying'),
#  ({'threat': True, 'dumbass': True}, 'Bullying'),
#  ({'jimmykimmel': True,
#    'trump': True,
#    'attack': True,
#    'getting': True,
#    'old': True,
#    'jimmy': True,
#    'piece': True,
#    'shit': True,
#    'kid': True,
#    'born': True,
#    'defective': True,
#    'b': True},
#   'Bullying'),
#  ({'.celestialsoph': True,
#    '.gibgirl1963': True,
#    '.legit.fag': True,
#    'interesting': True,
#    '..what': True,
#    'amp': True,
#    'title': True,
#    'yet': True},
#   'Non-Bullying'),
#  ({'kamalaharris': True,
#    'guess': True,
#    'nasty': True,
#    'libtard': True,
#    'like': True,
#    'rest': True,
#    'snowflakes..': True},
#   'Bullying'),
#  ({'hate': True,
#    'beg': True,
#    'life': True,
#    'as': True,
#    'mf': True,
#    "'like": True,
#    'bitch': True,
#    'know': True,
#    'effort': True,
#    "'trying": True,
#    'amp': True,
#    'begging': True,
#    'comple': True},
#   'Non-Bullying'),
#  ({'ivankatoworkday': True,
#    'fuck': True,
#    'piece': True,
#    'shit': True,
#    'liberal': True,
#    "'all": True,
#    'insulting': True,
#    'successful': True,
#    'people': True,
#    'failu': True},
#   'Bullying'),
#  ({'crazed': True,
#    'leftist': True,
#    'call': True,
#    'u': True,
#    'nazi\\': True,
#    'million': True,
#    'untapped': True,
#    'normy': True,
#    'mass': True,
#    'look': True,
#    'direction': True,
#    "'t": True},
#   'Non-Bullying'),
#  ({'meeting': True,
#    'speech': True,
#    'charming': True,
#    'british': True,
#    'person': True,
#    'told': True,
#    'brit': True,
#    'want': True,
#    'get': True,
#    'rid': True},
#   'Non-Bullying'),
#  ({"'m": True,
#    'logged': True,
#    'man': True,
#    'folk': True,
#    'really': True,
#    'tripping': True,
#    'old': True,
#    'dude': True,
#    'least': True,
#    'wait': True,
#    'dr': True},
#   'Non-Bullying'),
#  ({'attribute': True,
#    'miserable': True,
#    'fugly': True,
#    'bitter': True,
#    'demented': True,
#    'bitch': True,
#    'way': True,
#    'u': True,
#    'r': True,
#    'tuing': True,
#    'ur': True,
#    'bf': True,
#    'oops': True},
#   'Bullying'),
#  ({"'they": True,
#    'backward': True,
#    'low': True,
#    'iq': True,
#    'violent': True,
#    'barbar': True},
#   'Bullying'),
#  ({'one': True, 'noisy': True, 'goatfucker': True, 'ghost..': True},
#   'Bullying'),
#  ({'idiot': True,
#    'look': True,
#    'dave': True,
#    'gettlemans': True,
#    'draft': True,
#    'histor': True},
#   'Bullying'),
#  ({'run': True,
#    'away': True,
#    'cuban': True,
#    'heritage': True,
#    "'he": True,
#    'proud': True,
#    "'just": True,
#    'beca': True},
#   'Non-Bullying'),
#  ({'idiot': True, "'privilege": True, 'course': True}, 'Bullying'),
#  ({'let': True,
#    'give': True,
#    'nutella': True,
#    'filled': True,
#    'donut': True,
#    'shot': True,
#    'anything': True,
#    'important': True,
#    'like': True,
#    'party': True,
#    'leader': True,
#    'arm': True,
#    'around': True,
#    'gf': True,
#    'fag': True},
#   'Non-Bullying'),
#  ({'hey': True,
#    'stupid': True,
#    'cunt': True,
#    'fucking': True,
#    'dumb': True,
#    'shit': True,
#    'know': True,
#    'oh': True,
#    'yeah': True,
#    'way': True,
#    'pussy': True},
#   'Bullying'),
#  ({'holy': True,
#    'shit': True,
#    'fooking': True,
#    'retard': True,
#    'guess': True,
#    'happens': True,
#    'take': True,
#    'many': True,
#    'shot': True,
#    'noggin': True,
#    'eh': True,
#    'roid': True,
#    'raging': True,
#    'pos..': True},
#   'Bullying'),
#  ({'one': True,
#    'smile': True,
#    'quality': True,
#    'eternal': True,
#    'reassurance': True,
#    'may': True,
#    'come': True,
#    'across': True,
#    'four': True,
#    'f': True},
#   'Non-Bullying'),
#  ({'nigger': True, 'gyal': True, 'u': True, 'get': True, 'text': True},
#   'Bullying'),
#  ({'.fattydaddy7': True,
#    'flashback': True,
#    'august': True,
#    '1989': True,
#    'hamburg': True,
#    'germany': True,
#    'hooker': True,
#    'pull': True,
#    'shirt': True,
#    'head': True,
#    'hockey': True,
#    'fight': True},
#   'Non-Bullying'),
#  ({'king': True, 'show': True}, 'Non-Bullying'),
#  ({'.first': True,
#    'int': True,
#    'game': True,
#    'get': True,
#    '2': True,
#    'honor': True,
#    'mate': True,
#    'carry': True,
#    'uhhhhh': True,
#    'ky': True,
#    'pls': True},
#   'Non-Bullying'),
#  ({'gangster': True, 'pussy': True}, 'Bullying'),
#  ({'.goatfucker': True}, 'Non-Bullying'),
#  ({'retard': True}, 'Bullying'),
#  ({'muzzies': True,
#    'common': True,
#    'sense': True,
#    "'what": True,
#    'suppose': True,
#    'average': True,
#    'iq': True,
#    "'very": True,
#    'low': True,
#    'remain': True,
#    'illiterate': True,
#    "'look": True},
#   'Bullying'),
#  ({'bye': True, 'yes': True, 'fucking': True, 'dare': True, 'call': True},
#   'Non-Bullying'),
#  ({'dumbass': True, 'one': True, 'word..': True}, 'Non-Bullying'),
#  ({'ideology': True, 'trump': True, 'human': True, 'amazes': True},
#   'Non-Bullying'),
#  ({'law': True,
#    'goat': True,
#    'fuck': True,
#    'ironically': True,
#    'still': True,
#    'goatfucker': True,
#    "'stop": True,
#    'using': True,
#    'humor': True,
#    'excuse': True,
#    'justify': True,
#    'p': True},
#   'Bullying'),
#  ({'.i': True,
#    'hate': True,
#    'ppl': True,
#    'buy': True,
#    'totw': True,
#    'version': True,
#    'card': True,
#    'get': True,
#    'power': True,
#    "'like": True,
#    'foreal': True,
#    'ky': True},
#   'Non-Bullying'),
#  ({'.hillaryclinton': True,
#    'make': True,
#    'feel': True,
#    'like': True,
#    'bigger': True,
#    'person': True,
#    'insult': True,
#    'others': True,
#    'think': True,
#    'probably': True,
#    'b': True},
#   'Non-Bullying'),
#  ({'quoting': True,
#    'hannity': True,
#    'biggest': True,
#    'liar': True,
#    'congress': True,
#    "'you": True,
#    'pathetic': True,
#    'loser': True,
#    'political': True,
#    'hack..': True},
#   'Bullying'),
#  ({'sum': True,
#    'i\\': True,
#    "'m": True,
#    'twitter': True,
#    'want': True,
#    'hear': True,
#    'opinion': True,
#    'similar': True,
#    'mine': True,
#    'hate': True,
#    'half': True,
#    'americ': True},
#   'Non-Bullying'),
#  ({'stevescalise': True,
#    'realdonaldtrump': True,
#    'another': True,
#    'leftist': True,
#    'libtard': True,
#    'hater': True,
#    'assuming': True,
#    'using': True,
#    'god': True,
#    'hatef': True},
#   'Bullying'),
#  ({'think': True,
#    'time': True,
#    'reclaim': True,
#    'feminism': True,
#    'radical': True,
#    'try': True,
#    'diminish': True,
#    'woman': True,
#    'achievement': True,
#    'conflat': True},
#   'Non-Bullying'),
#  ({'.oh': True,
#    'bullshit': True,
#    '.realdonaldtrump': True,
#    "'you": True,
#    'lost': True,
#    'popular': True,
#    'vote': True,
#    'u': True,
#    'know': True,
#    'incompetent': True,
#    'idiot': True,
#    'are..': True},
#   'Bullying'),
#  ({'dumbass': True,
#    'processed': True,
#    'nipple': True,
#    'piercing': True,
#    'dkfjkd': True},
#   'Non-Bullying'),
#  ({'must': True,
#    'say': True,
#    '.pewdiepie': True,
#    'least': True,
#    'alt-right': True,
#    'scumbag': True,
#    'might': True,
#    'hone': True,
#    'missile': True,
#    'f': True},
#   'Non-Bullying'),
#  ({'fuck': True,
#    'lady': True,
#    'libtard': True,
#    'asshole': True,
#    'like': True,
#    'ruining': True,
#    'country.': True,
#    'instead': True,
#    'helping': True,
#    'secure': True,
#    'board': True},
#   'Bullying'),
#  ({'youre': True,
#    'pussy': True,
#    'hope': True,
#    'pitbull': True,
#    'bite': True,
#    'as': True,
#    'judging': True,
#    'youll': True,
#    'mad': True},
#   'Bullying'),
#  ({'wait': True,
#    'minute': True,
#    'saying': True,
#    'magician': True,
#    'libtard': True,
#    'myth': True,
#    'dirty': True,
#    'scoundrel': True},
#   'Bullying'),
#  ({'im': True,
#    'comparing': True,
#    'williamson': True,
#    'ingraham': True,
#    'eriksson': True,
#    'mlk': True,
#    'dixie': True,
#    'chick': True,
#    "'if": True,
#    'believe': True},
#   'Non-Bullying'),
#  ({'goatfucker': True}, 'Non-Bullying'),
#  ({'ur': True,
#    'whole': True,
#    'dumbass': True,
#    'tf': True,
#    'right': True,
#    'mind': True,
#    'would': True,
#    'say': True,
#    'people': True},
#   'Bullying'),
#  ({'dumb': True,
#    'fuck': True,
#    'sort': True,
#    'game': True,
#    'keep': True,
#    'freezing': True,
#    'dying': True,
#    'fall': True,
#    'damage': True},
#   'Bullying'),
#  ({'.i': True,
#    'hate': True,
#    'otome': True,
#    "'its": True,
#    'call': True,
#    'duty': True,
#    "'you": True,
#    'crazy': True,
#    'liking': True,
#    'girly': True,
#    'game': True,
#    "'play": True,
#    'real': True,
#    'ca': True},
#   'Non-Bullying'),
#  ({'sneadi': True,
#    'punch': True,
#    'fameles': True,
#    'shit': True,
#    'nvm': True,
#    'lol': True,
#    'also': True,
#    'beating': True,
#    'woman': True,
#    'idiot': True,
#    'fag': True},
#   'Bullying'),
#  ({'new': True,
#    'gospel': True,
#    'woman': True,
#    'katharine': True,
#    'bushnell': True,
#    'challenge': True,
#    'christian': True,
#    'feminism': True,
#    '.oupacademic': True},
#   'Non-Bullying'),
#  ({'salivating': True,
#    'worthless': True,
#    'piece': True,
#    'shit': True,
#    'need': True,
#    'keep': True,
#    'clean': True,
#    'lickthemcleanbitch': True,
#    'dom': True,
#    'footfetish': True,
#    '.bri': True},
#   'Bullying'),
#  ({'realdonaldtrump': True, 'stop': True, 'yelling..': True}, 'Non-Bullying'),
#  ({'got': True,
#    'ta': True,
#    'nice': True,
#    'people': True,
#    'fuck': True,
#    "don\\'t": True},
#   'Non-Bullying'),
#  ({'.see': True,
#    'wanted': True,
#    'type': True,
#    'duck': True,
#    'instead': True,
#    'fuck': True,
#    'fucking': True,
#    'would': True,
#    "'.apple": True,
#    'stop': True,
#    'trying': True,
#    'pg': True,
#    'message': True},
#   'Non-Bullying'),
#  ({'.a': True,
#    'classic': True,
#    'article': True,
#    'worth': True,
#    'reading': True,
#    'anew': True,
#    'via': True,
#    '.harpers': True},
#   'Non-Bullying'),
#  ({'one': True,
#    'good': True,
#    'thing': True,
#    'og': True,
#    "'re": True,
#    'bringing': True,
#    'eu': True,
#    'master': True,
#    'fuck': True,
#    'ton': True,
#    'publicity': True,
#    'going': True},
#   'Non-Bullying'),
#  ({'also': True, 'muslim': True, "'what": True, 'goatfucker': True},
#   'Bullying'),
#  ({'ca': True, 'ky': True, 'love': True, 'many': True, 'people': True},
#   'Non-Bullying'),
#  ({'meaht': True, 'fag': True, 'lol': True}, 'Bullying'),
#  ({'naw': True,
#    'would': True,
#    'disgustingly': True,
#    'fat': True,
#    'as': True,
#    'pimped': True,
#    'every': True,
#    'wannabe': True,
#    'thug': True,
#    'rapper': True,
#    'unt': True},
#   'Bullying'),
#  ({'..dloesch': True,
#    'one': True,
#    'constitutional': True,
#    'right': True,
#    'six-figure': True,
#    'position': True,
#    'writing': True,
#    'atlantic..': True},
#   'Non-Bullying'),
#  ({'ingrahamangle': True, 'short': True, 'fat': True, 'slut..': True},
#   'Bullying'),
#  ({'connor': True,
#    'got': True,
#    'ditched': True,
#    'lt': True,
#    '14:05:28': True,
#    'friiends': True,
#    '14:05:32': True,
#    'gt': True,
#    'rank': True,
#    'gone': True,
#    '14:05:56': True,
#    'c': True},
#   'Non-Bullying'),
#  ({'hey': True,
#    'foxandfriends': True,
#    'next': True,
#    'time': True,
#    'propose': True,
#    'dumbass': True,
#    'idea': True,
#    'like': True,
#    'militarizing': True,
#    'border': True,
#    'sure': True,
#    'include': True},
#   'Non-Bullying'),
#  ({'realdonaldtrump': True, 'truly': True, 'idiot': True}, 'Bullying'),
#  ({'comment': True, 'takin': True}, 'Non-Bullying'),
#  ({'well': True,
#    'also': True,
#    'pranking': True,
#    'bit': True,
#    'bitch': True,
#    'time': True,
#    'thought': True},
#   'Bullying'),
#  ({'snitch': True, 'ky': True}, 'Non-Bullying'),
#  ({'swear': True, 'people': True, 'iq': True, 'insanely': True, 'low': True},
#   'Bullying'),
#  ({'remark': True,
#    'tusk': True,
#    'european': True,
#    'cheap': True,
#    'whore': True,
#    'smelly': True,
#    'goatfucker': True,
#    'turkey..': True},
#   'Non-Bullying'),
#  ({'rob': True,
#    'reiner': True,
#    'say': True,
#    'one': True,
#    'watch': True,
#    'new': True,
#    'roseannebarr': True,
#    'show': True,
#    'nazi': True,
#    '..': True,
#    "'lets": True,
#    'give': True,
#    'ol': True,
#    'anti': True,
#    'patriot': True,
#    'salut': True},
#   'Non-Bullying'),
#  ({'willful': True,
#    'blindness': True,
#    'dangerous': True,
#    'outright': True,
#    'prejudice': True,
#    'perhaps': True},
#   'Non-Bullying'),
#  ({'pathetic': True,
#    'loser': True,
#    "'russia": True,
#    'russia': True,
#    "'with": True,
#    'proof': True,
#    "'what": True,
#    'buffoon': True},
#   'Bullying'),
#  ({'realdonaldtrump': True,
#    'let': True,
#    'continue': True,
#    'bloated': True,
#    'boob': True,
#    'mean': True,
#    'really': True,
#    'donny': True,
#    'fool': True,
#    'buffoon': True,
#    "'betw": True},
#   'Bullying'),
#  ({'..republicannba': True, '.manalarba': True, 'wtf': True, 'nigger': True},
#   'Non-Bullying'),
#  ({'.i': True,
#    '44': True,
#    'martin': True,
#    'luther': True,
#    'king': True,
#    'assassinated': True,
#    'family': True,
#    'young': True,
#    'amp': True,
#    'remember': True,
#    'along': True,
#    'wife': True,
#    'sitting': True},
#   'Non-Bullying'),
#  ({'.whenever': True,
#    'see': True,
#    'photo': True,
#    'girl': True,
#    'wt': True,
#    'snapchat': True,
#    'heart': True,
#    'filter': True,
#    'take': True,
#    'admission': True,
#    'gulit': True,
#    'fugly': True},
#   'Non-Bullying'),
#  ({'president': True,
#    'trump': True,
#    'dems': True,
#    'promised': True,
#    '50': True,
#    'year': True,
#    'nothing': True,
#    '..you': True,
#    'asshole': True},
#   'Bullying'),
#  ({'.nntaleb': True,
#    '1': True,
#    'low-iq-arabists': True,
#    'trying': True,
#    'smear': True,
#    'racist': True,
#    'minority': True,
#    "don\\'t": True,
#    'identify': True,
#    'w/arabism': True,
#    'clueless': True,
#    '+not': True,
#    'arab': True,
#    "doesn\\'t": True},
#   'Non-Bullying'),
#  ({'low': True,
#    'iq': True,
#    'gross': True,
#    'would': True,
#    'excuse': True,
#    'murdering': True,
#    'someone': True},
#   'Non-Bullying'),
#  ({'fugly': True,
#    'thought': True,
#    'gif': True,
#    'tapped': True,
#    'play': True,
#    'work': True,
#    'phone': True,
#    'speaker': True,
#    'loud': True},
#   'Non-Bullying'),
#  ({'must': True,
#    'stand': True,
#    'prejudice': True,
#    'discrimination': True,
#    'society': True,
#    "'communities": True,
#    'built': True,
#    'people': True,
#    'coming': True,
#    'together': True},
#   'Non-Bullying'),
#  ({'fuck': True, 'coinbase': True}, 'Non-Bullying'),
#  ({'.i': True,
#    'bought': True,
#    '3': True,
#    'hot': True,
#    'dog': True,
#    'target': True,
#    'cafe': True,
#    "'everyone": True,
#    'said': True,
#    'awe': True,
#    'got': True,
#    'snack': True,
#    'family': True,
#    'like': True,
#    'bitch': True},
#   'Non-Bullying'),
#  ({'shush': True, "'be": True, 'quiet': True, 'goatfucker..': True},
#   'Bullying'),
#  ({'e': True,
#    'mohammed': True,
#    'undoubtedly': True,
#    'extremely': True,
#    'low': True,
#    'iq': True,
#    'near': True,
#    'certainty': True},
#   'Bullying'),
#  ({'call': True,
#    'pimp': True,
#    'loser': True,
#    'cuck': True,
#    'sissyslut': True,
#    'fag': True,
#    'cunt': True,
#    'homewrecker': True,
#    'pathetic': True,
#    'hand': True,
#    'fucker': True,
#    'tinywinne': True},
#   'Bullying'),
#  ({'another': True,
#    'nasty': True,
#    'piece': True,
#    'shit': True,
#    'cunt': True,
#    'getting': True,
#    'fucking': True,
#    'asshole': True,
#    'blown': True,
#    'apart': True},
#   'Bullying'),
#  ({'talking': True,
#    'running': True,
#    'bus': True,
#    'full': True,
#    'randoms': True,
#    'gang': True,
#    'friend': True,
#    'like': True,
#    'abso': True},
#   'Non-Bullying'),
#  ({'big': True,
#    'difference': True,
#    'libtard': True,
#    'leftist/liberal': True,
#    "'if": True,
#    'viewpoint': True,
#    'opposes': True,
#    'mine': True},
#   'Non-Bullying'),
#  ({'secretly': True, 'absolute': True, 'idiot': True, 'too..': True},
#   'Non-Bullying'),
#  ({'dotus': True,
#    'dumbass': True,
#    'united': True,
#    'state': True,
#    'really': True,
#    'losing': True,
#    'week': True,
#    "'scary": True,
#    'time': True},
#   'Non-Bullying'),
#  ({'low': True,
#    'iq': True,
#    'statement': True,
#    'justifying': True,
#    'shooter': True,
#    'fact': True},
#   'Non-Bullying'),
#  ({'top': True,
#    '1': True,
#    'ky': True,
#    'see': True,
#    'average': True,
#    'tax': True,
#    'cut': True,
#    '7086': True,
#    "'people": True,
#    'make': True,
#    '175000': True,
#    '427000': True,
#    'yr': True,
#    'cu': True},
#   'Non-Bullying'),
#  ({'internet': True,
#    'biggest': True,
#    'nazi': True,
#    'website': True,
#    'facing': True,
#    'financial': True,
#    'meltdown': True,
#    'stormfront': True,
#    'daily': True,
#    'stormer': True,
#    'day': True,
#    'might': True},
#   'Non-Bullying'),
#  ({'oh': True,
#    'know': True,
#    '..new': True,
#    'titan': True,
#    'unis': True,
#    'fugly': True,
#    "'keep": True,
#    'enjoying': True,
#    'mayo': True},
#   'Non-Bullying'),
#  ({'fugly': True,
#    'lib': True,
#    'slob': True,
#    't-shirt': True,
#    'message': True,
#    'unnecessary': True,
#    "'all": True,
#    'men': True,
#    'would': True,
#    'ce': True},
#   'Bullying'),
#  ({'pathetic': True,
#    'loser': True,
#    'send': True,
#    'money': True,
#    'paypig': True,
#    'findom': True,
#    'fendom': True,
#    'cashslave': True},
#   'Bullying'),
#  ({'fugly': True, 'fuckin': True, 'ugly': True, 'inside': True}, 'Bullying'),
#  ({'lol': True,
#    'think': True,
#    'one': True,
#    'calling': True,
#    'retard': True,
#    'etc..': True},
#   'Non-Bullying'),
#  ({'.all': True,
#    'bitch': True,
#    'fugly': True,
#    'smoking': True,
#    'dope': True,
#    'like': True,
#    'junky': True},
#   'Non-Bullying'),
#  ({'got': True,
#    'notification': True,
#    "'please": True,
#    "'for": True,
#    'love': True,
#    'god': True,
#    'nobody': True,
#    'care': True,
#    'decade': True,
#    'old': True,
#    'story': True,
#    'e': True},
#   'Non-Bullying'),
#  ({'different': True,
#    'opinion': True,
#    "'you": True,
#    'think': True,
#    'ignorant': True,
#    'libtard': True},
#   'Non-Bullying'),
#  ({'thing': True,
#    'blow': True,
#    'mind': True,
#    'fact': True,
#    'apparently': True,
#    'punch': True,
#    'wall': True,
#    'american': True,
#    'house': True,
#    'dent': True,
#    "'like": True,
#    'actually': True,
#    'bre': True},
#   'Non-Bullying'),
#  ({'realdonaldtrump': True,
#    'mr': True,
#    'donald': True,
#    'trump': True,
#    'worst': True,
#    'person': True,
#    'exists': True,
#    'usa': True,
#    'look': True,
#    'like': True,
#    'hitler': True},
#   'Bullying'),
#  ({'arctic': True,
#    'monkey': True,
#    'post': True,
#    'malone': True,
#    'released': True,
#    'album': True,
#    'date': True,
#    'today': True,
#    'good': True,
#    'day': True},
#   'Non-Bullying'),
#  ({'ky': True, 'ugly': True}, 'Bullying'),
#  ({'also': True,
#    'dismissed': True,
#    'argument': True,
#    'called': True,
#    'russian': True,
#    'bot': True,
#    'ye': True},
#   'Non-Bullying'),
#  ({'mean': True,
#    'like': True,
#    'conservative': True,
#    'label': True,
#    'everyone': True,
#    'liking': True,
#    'rino': True},
#   'Non-Bullying'),
#  ({'glennbeck': True,
#    '.dloesch': True,
#    '.bluelivesmatter': True,
#    'mean': True},
#   'Bullying'),
#  ({'rakitic': True,
#    'bossing': True,
#    'kroos': True,
#    '2': True,
#    'time': True,
#    'season': True,
#    'god': True,
#    'know': True,
#    'long': True,
#    'apparently': True,
#    'lucho': True,
#    'turning': True,
#    'overhyp': True},
#   'Non-Bullying'),
#  ({'bad': True, 'personal': True, 'prejudice': True, 'prej': True},
#   'Non-Bullying'),
#  ({'prefer': True,
#    'call': True,
#    'dimwit': True,
#    "'dumbass": True,
#    'bit': True,
#    'harsh': True,
#    "'inbred": True,
#    'knuckle': True,
#    'dragging': True,
#    'mouth': True,
#    'breather': True,
#    'would': True},
#   'Bullying'),
#  ({'stop': True,
#    'cry': True,
#    'moron': True,
#    'fighter': True,
#    'pussy': True,
#    "'do": True,
#    'want': True,
#    'famous': True,
#    "'ohh": True,
#    'thats': True,
#    'problem': True},
#   'Bullying'),
#  ({'..christywebs3': True,
#    '.somedawson': True,
#    '.parieobrien': True,
#    '.camilalloyd7': True,
#    '.billboard': True,
#    'rude': True,
#    'person': True,
#    'come': True,
#    'j': True},
#   'Non-Bullying'),
#  ({'.that': True,
#    'pansy': True,
#    'mike': True,
#    'cernovich': True,
#    'blocked': True,
#    'periscope': True,
#    'said': True,
#    'irrelevant': True,
#    "'here": True,
#    'tear': True,
#    'mikey': True,
#    'dumbass': True},
#   'Bullying'),
#  ({'coworkers': True,
#    'always': True,
#    'tryna': True,
#    'add': True,
#    'social': True,
#    'medium': True,
#    "'like": True,
#    'calling': True,
#    'come': True,
#    'cause': True,
#    'emergency': True},
#   'Non-Bullying'),
#  ({'donald': True,
#    'trump': True,
#    'idiot': True,
#    'pathetic': True,
#    'loser': True,
#    'liar': True,
#    'king': True,
#    'fake': True,
#    'news': True},
#   'Bullying'),
#  ({'nobody': True,
#    'care': True,
#    'sharon': True,
#    'pathetic': True,
#    'loser..': True},
#   'Bullying'),
#  ({'pussy': True,
#    'fan': True,
#    'anymore': True,
#    'douche': True,
#    "'you": True,
#    'ashamed': True,
#    'man': True},
#   'Bullying'),
#  ({'2a': True, 'guy': True, 'anybody': True, 'also': True, 'person': True},
#   'Non-Bullying'),
#  ({'realdonaldtrump': True,
#    "'ll": True,
#    'never': True,
#    'able': True,
#    'call': True,
#    'anything': True,
#    'else': True},
#   'Non-Bullying'),
#  ({'.hey': True,
#    "'this": True,
#    'guy': True,
#    'smell': True,
#    'like': True,
#    'canadian': True,
#    'joke': True,
#    'dumbass': True,
#    'snowflake': True},
#   'Bullying'),
#  ({'shut': True,
#    'fuck': True,
#    'stupid': True,
#    'gipsy': True,
#    'unarmed': True,
#    'man': True,
#    'shot': True,
#    'back': True,
#    'u': True,
#    'goatfucker..': True},
#   'Bullying'),
#  ({'.the': True,
#    'girl': True,
#    'quoting': True,
#    'man': True,
#    'never': True,
#    'leave': True,
#    'house': True,
#    'wearing': True,
#    'tweet': True,
#    'ca': True},
#   'Non-Bullying'),
#  ({'.attn': True,
#    'wrestler': True,
#    'attending': True,
#    '.wrestlecon': True,
#    'cool': True,
#    'one': True,
#    'another': True,
#    'asshole': True,
#    'like': True,
#    'douchebag': True,
#    'j': True},
#   'Non-Bullying'),
#  ({'dubai': True, "'-": True, '10': True}, 'Non-Bullying'),
#  ({'idea': True,
#    'like': True,
#    '100': True,
#    'october': True,
#    '99': True,
#    'post': True,
#    'idolshit': True,
#    'idk': True,
#    "'m": True,
#    'getting': True,
#    'dumbass': True,
#    'clout': True},
#   'Non-Bullying'),
#  ({'bullshit': True,
#    'worthless': True,
#    'piece': True,
#    'shit': True,
#    "'your": True,
#    'whole': True,
#    'agenda': True,
#    'wisconsin': True,
#    'fucking': True},
#   'Bullying'),
#  ({'tech': True,
#    'medium': True,
#    'moved': True,
#    'unholy': True,
#    'racist': True,
#    'alliance': True,
#    'basically': True,
#    'offered': True,
#    'left': True,
#    'feminism': True,
#    'economy': True,
#    'pri': True},
#   'Non-Bullying'),
#  ({'cheer': True}, 'Non-Bullying'),
#  ({'nope': True, 'low': True, 'iq': True, 'breeding': True}, 'Bullying'),
#  ({'quit': True,
#    'limiting': True,
#    'account': True,
#    'without': True,
#    'explanation': True,
#    "'you": True,
#    'censoring': True,
#    'justification': True},
#   'Non-Bullying'),
#  ({'incase': True,
#    'understand': True,
#    'gaslight': True,
#    'cyber-weapons': True,
#    'use': True,
#    'owl': True,
#    'logo': True,
#    'dumbass': True,
#    'pedo': True,
#    '666': True,
#    'shrimpdick': True,
#    'sign': True},
#   'Non-Bullying'),
#  ({'beating': True,
#    'white': True,
#    'people': True,
#    'say': True,
#    'nigger': True,
#    'posting': True,
#    'social': True,
#    'medium': True},
#   'Bullying'),
#  ({'always': True,
#    'much': True,
#    'hatred': True,
#    'prejudice': True,
#    'internet': True,
#    'exposed': True,
#    'effective': True},
#   'Non-Bullying'),
#  ({'ky': True, 'x': True}, 'Bullying'),
#  ({'yeah': True,
#    "'m": True,
#    'gender': True,
#    'critical': True,
#    'feminist': True,
#    'lot': True,
#    'like': True,
#    'feminism': True,
#    'except': True,
#    'instead': True,
#    'bully': True,
#    'child': True,
#    'conf': True},
#   'Non-Bullying'),
#  ({'conor': True,
#    "'re": True,
#    'fucking': True,
#    'retard': True,
#    'fuck': True,
#    'like': True,
#    'ufc223': True},
#   'Bullying'),
#  ({'making': True,
#    'supporting': True,
#    'mean': True,
#    'either': True,
#    'asshole': True,
#    'irish': True,
#    'asshole*': True,
#    'point': True},
#   'Non-Bullying'),
#  ({'find': True,
#    'disturbing': True,
#    'someone': True,
#    'say': True,
#    'especially': True,
#    'witness': True,
#    'nazi': True,
#    'germany': True},
#   'Non-Bullying'),
#  ({'man': True,
#    'mouse': True,
#    "'stop": True,
#    'begging': True,
#    'act': True,
#    'pussy': True},
#   'Bullying'),
#  ({'best': True,
#    'person': True,
#    'job': True,
#    'always': True,
#    'seem': True,
#    'straight': True,
#    'white': True,
#    'middle-aged': True,
#    'middle-class': True,
#    'man': True,
#    '.anoosh.c': True},
#   'Non-Bullying'),
#  ({'blackmail': True,
#    'prejudice': True,
#    'persecution': True,
#    'gay': True,
#    'right': True,
#    'nigeria': True},
#   'Non-Bullying'),
#  ({'fire': True,
#    'prejudice': True,
#    "'it": True,
#    'happen': True,
#    'anyone': True,
#    'place': True,
#    'time': True,
#    'campus': True,
#    'country': True,
#    'simo': True},
#   'Non-Bullying'),
#  ({'msnbc': True,
#    'poll': True,
#    'soros': True,
#    'became': True,
#    'obama': True,
#    'biggest': True,
#    'financial': True,
#    'sugar': True,
#    'daddy': True,
#    'right': True,
#    'time': True,
#    'started': True,
#    'happen..': True},
#   'Non-Bullying'),
#  ({'.yes': True,
#    'emotional': True,
#    'yes': True,
#    'complete': True,
#    'dumbass': True,
#    'sometimes': True,
#    'loud': True,
#    'hell': True,
#    'love': True,
#    'people': True},
#   'Non-Bullying'),
#  ({'.today': True,
#    'punishamuslimday': True,
#    "'there": True,
#    'day': True,
#    'never': True,
#    "'today": True,
#    'remind': True,
#    'muslim': True},
#   'Non-Bullying'),
#  ({'award': True,
#    'low': True,
#    'iq': True,
#    'tweet': True,
#    'week': True,
#    'go': True},
#   'Bullying'),
#  ({'.kamalaharris': True,
#    'loser': True,
#    "'hey": True,
#    'kamala': True,
#    'related': True,
#    'low': True,
#    'iq': True,
#    'maxine': True},
#   'Bullying'),
#  ({'pussy': True,
#    'khabib': True,
#    "'you": True,
#    'laugh': True,
#    'inside': True,
#    "'shut": True,
#    'vagina': True,
#    'pick': True,
#    'som': True},
#   'Bullying'),
#  ({'defend': True,
#    'someone': True,
#    'saying': True,
#    'nigger': True,
#    'racist': True,
#    'go': True,
#    'hell': True},
#   'Non-Bullying'),
#  ({'attorney': True,
#    'nebraska': True,
#    'death': True,
#    'row': True,
#    'inmate': True,
#    'john': True,
#    'lotter': True,
#    'iq': True,
#    'low': True,
#    'execution': True,
#    'via': True,
#    '.owhnews': True},
#   'Non-Bullying'),
#  ({'jew': True,
#    'nazi-occupied': True,
#    'czechoslovakia': True,
#    'ordered': True,
#    'assemble': True,
#    'synagogue': True,
#    'census': True,
#    "'in": True,
#    'fact': True,
#    'germa': True},
#   'Non-Bullying'),
#  ({'wow': True, 'fag': True}, 'Bullying'),
#  ({'maxine': True,
#    'water': True,
#    'ultimate': True,
#    'low': True,
#    'iq': True,
#    'collection': True,
#    'tfnoriginal': True,
#    'via': True,
#    '.youtube': True},
#   'Bullying'),
#  ({'ky': True, 'cuck': True}, 'Bullying'),
#  ({'girl': True,
#    'nastiest': True,
#    'skank': True,
#    'bitch': True,
#    "'ve": True,
#    'ever': True,
#    'met': True,
#    "'do": True,
#    'trust': True,
#    "'she": True,
#    'fugly': True,
#    'slut': True},
#   'Bullying'),
#  ({'conor': True,
#    'mcgregor': True,
#    'fucking': True,
#    'gangster': True,
#    'clown': True,
#    'becoming': True,
#    'famous': True,
#    'cunt': True,
#    'fighter': True,
#    'khab': True},
#   'Bullying'),
#  ({'.my': True,
#    'day': True,
#    'terrible': True,
#    'dumbass': True,
#    'got': True,
#    'car': True,
#    'put': True,
#    'park': True,
#    'almost': True,
#    'crashed': True,
#    'corner': True,
#    'store': True,
#    'like': True,
#    'wtf': True,
#    '\\u200d': True},
#   'Non-Bullying'),
#  ({'donkey': True,
#    "'from": True,
#    'best': True,
#    'uniform': True,
#    'fugly': True,
#    'orange': True,
#    'blue': True,
#    "'good": True,
#    'riddance': True,
#    'gruden': True,
#    'tolerate': True,
#    'nonsense': True},
#   'Bullying'),
#  ({'.fuck': True, 'narrow': True, 'minded': True}, 'Non-Bullying'),
#  ({'2': True,
#    'fan': True,
#    'gave': True,
#    'mikey': True,
#    'panic': True,
#    'attack': True,
#    'fuck': True,
#    'made': True,
#    'luke': True,
#    'angry': True,
#    'yell': True},
#   'Non-Bullying'),
#  ({'findom': True,
#    'woke': True,
#    'thailand': True,
#    'gf': True,
#    'next': True,
#    'easy': True,
#    'fuck': True,
#    'first': True,
#    'thing': True,
#    'mind': True,
#    'go': True,
#    'outside': True,
#    'log': True,
#    'f': True},
#   'Non-Bullying'),
#  ({'legacy': True, 'league': True, 'nigga': True, 'junbay': True},
#   'Non-Bullying'),
#  ({'.lookin': True, 'real': True, 'fugly': True}, 'Bullying'),
#  ({'pathetic': True,
#    'loser': True,
#    "'to": True,
#    'think': True,
#    'admired': True,
#    'sucka**': True,
#    'one': True,
#    'point..': True},
#   'Bullying'),
#  ({'think': True,
#    'illegals': True,
#    'threat': True,
#    'idiot': True,
#    "'one": True,
#    'need': True,
#    'look': True,
#    'european': True,
#    'country': True,
#    'know': True},
#   'Bullying'),
#  ({'.follow': True,
#    '.symeonbrown': True,
#    'tonight': True,
#    'tottenham': True,
#    "'no": True,
#    'better': True,
#    'reporter': True,
#    'grief': True,
#    'rage': True,
#    'prejudice': True,
#    'injustice': True,
#    'captur': True},
#   'Non-Bullying'),
#  ({'.mind': True,
#    'talking': True,
#    'shit': True,
#    'philadelphia': True,
#    'winning': True,
#    'championship': True,
#    "'his": True,
#    'response': True},
#   'Non-Bullying'),
#  ({'rant': True,
#    '-practice': True,
#    'make': True,
#    'suicidal': True,
#    '-i': True,
#    'hate': True,
#    'people': True,
#    'cocky': True,
#    '-if': True,
#    'say': True,
#    "'re": True,
#    'going': True,
#    'something': True,
#    'pro': True},
#   'Non-Bullying'),
#  ({'sent': True,
#    'snap': True,
#    'asscheek': True,
#    'facing': True,
#    'mirror': True,
#    'bathroom': True,
#    'nude': True,
#    'like': True,
#    'finally..': True},
#   'Non-Bullying'),
#  ({'fugly': True,
#    'alright': True,
#    'starting': True,
#    'get': True,
#    'headache': True},
#   'Non-Bullying'),
#  ({'shockingly': True,
#    'iran': True,
#    '2nd': True,
#    'world': True,
#    'transition': True,
#    'bc': True,
#    'homosexuality': True,
#    'still': True,
#    'carry': True},
#   'Non-Bullying'),
#  ({'another': True, 'insecure': True, 'fag': True, 'suprsie': True},
#   'Bullying'),
#  ({'guy': True,
#    'douglas': True,
#    'mackey': True,
#    '28': True,
#    'went': True,
#    'middlebury': True,
#    'son': True,
#    'lobbyist': True,
#    'scott': True,
#    'life': True,
#    'manhattan': True,
#    "'he": True,
#    'nazi': True,
#    'hug': True},
#   'Non-Bullying'),
#  ({'prejudice': True,
#    'jew': True,
#    'cropping': True,
#    'among': True,
#    'migrant': True,
#    'fear': True,
#    'grow': True,
#    'new': True,
#    'generation': True,
#    'anti-semite': True,
#    'comin': True},
#   'Non-Bullying'),
#  ({'.realdonaldtrump': True,
#    'one': True,
#    'lying': True,
#    'son': True,
#    'bitch': True,
#    "'it": True,
#    'would': True,
#    'thing': True,
#    'could': True,
#    'lie': True,
#    'well': True},
#   'Bullying'),
#  ({'follow': True,
#    'libtard': True,
#    'muslim': True,
#    'ate': True,
#    'involved': True,
#    'blm': True,
#    '3': True,
#    'er': True},
#   'Bullying'),
#  ({'ky': True, 'childhood': True, 'playing': True, 'rock': True},
#   'Non-Bullying'),
#  ({'feeling': True, 'start': True, 'fuck': True}, 'Non-Bullying'),
#  ({'.dumbass': True, 'dodie..': True}, 'Bullying'),
#  ({'.striving': True,
#    '2b': True,
#    'first': True,
#    'worthless': True,
#    'objective': True,
#    '~tl': True,
#    'openmind': True,
#    '2': True,
#    'seek': True,
#    'perspective': True,
#    'observe': True,
#    'question': True},
#   'Non-Bullying'),
#  ({'.if': True,
#    'anything': True,
#    'u': True,
#    'say': True,
#    'wit': True,
#    'certainty': True,
#    'devin': True,
#    'nunes': True,
#    '15': True,
#    'minute': True,
#    'fame': True,
#    'tru': True},
#   'Non-Bullying'),
#  ({'gaining': True, 'asshole': True}, 'Bullying'),
#  ({'wake': True,
#    'retard': True,
#    'lost': True,
#    'team': True,
#    'online': True,
#    'tourney': True,
#    'remember': True,
#    'one': True},
#   'Bullying'),
#  ({'.sometimes': True,
#    'man': True,
#    'got': True,
#    'ta': True,
#    'scooby': True,
#    'dooby': True,
#    'doo': True,
#    'uhhh': True,
#    'dog': True,
#    'dumbass': True,
#    'le': True},
#   'Non-Bullying'),
#  ({'like': True,
#    'doctor': True,
#    'play': True,
#    "'you": True,
#    'tough': True,
#    'guy': True,
#    'complete': True,
#    'pussy..': True},
#   'Bullying'),
#  ({'idiot': True, 'think': True, 'ram': True, 'already': True, 'h': True},
#   'Non-Bullying'),
#  ({'ask': True,
#    'dumbass': True,
#    'question': True,
#    'want': True,
#    'smart': True,
#    'as': True,
#    'response': True},
#   'Bullying'),
#  ({'vin': True,
#    'diesel': True,
#    'closet': True,
#    'fag': True,
#    'know': True,
#    'rock': True,
#    'worried': True,
#    'made': True,
#    'money': True,
#    'one': True,
#    'yea': True},
#   'Bullying'),
#  ({'lecture': True,
#    'april': True,
#    '11': True,
#    '5:30pm': True,
#    'joseph': True,
#    'winter': True,
#    'world': True,
#    'anti-': True,
#    'blackness': True,
#    'coates': True,
#    'afro-pessimism': True,
#    'rupture': True},
#   'Non-Bullying'),
#  ({'playing': True,
#    'monster': True,
#    'exo': True,
#    'yes': True,
#    'im': True,
#    'dancing': True,
#    'like': True,
#    'nobody': True,
#    'watching': True,
#    'dont': True,
#    'care..': True,
#    "'enjoy": True},
#   'Non-Bullying'),
#  ({'literally': True,
#    'know': True,
#    'one': True,
#    'person': True,
#    'us': True,
#    'word': True,
#    'fugly': True,
#    "'lol": True,
#    'fuck': True,
#    'anna..': True},
#   'Non-Bullying'),
#  ({'young': True,
#    'blood': True,
#    'next': True,
#    'single': True,
#    "'and": True,
#    'going': True,
#    'fucking': True,
#    'music': True,
#    'video': True,
#    "'bitch": True,
#    'fuck': True},
#   'Bullying'),
#  ({'baby': True,
#    'army': True,
#    'irl': True,
#    'first': True,
#    'comeback': True,
#    'trying': True,
#    'explain': True,
#    'euphoria': True,
#    'teaser': True,
#    'linking': True,
#    'mv': True,
#    'cu': True},
#   'Non-Bullying'),
#  ({'..spann': True,
#    'happened': True,
#    'manner': True,
#    'someone': True,
#    'momma': True,
#    'teach': True,
#    'right': True,
#    "'talking": True,
#    'man': True,
#    'show': True,
#    'u': True,
#    'weather': True},
#   'Non-Bullying'),
#  ({'.lol': True,
#    'literally': True,
#    'chased': True,
#    'dad': True,
#    'dog': True,
#    'around': True,
#    'house': True,
#    'picked': True,
#    'fuck': True,
#    'amp': True,
#    'threw': True,
#    'onto': True,
#    'p': True},
#   'Non-Bullying'),
#  ({'pathetic': True,
#    'slave': True,
#    'life': True,
#    "'thats": True,
#    'tribute': True,
#    'dont': True,
#    'need': True,
#    'money': True,
#    'go': True,
#    'findom': True,
#    'fi': True},
#   'Bullying'),
#  ({'yeah': True,
#    'mate': True,
#    'must': True,
#    'get': True,
#    'many': True,
#    'fight': True,
#    'fucking': True,
#    'hard': True,
#    'nut': True,
#    'fighting': True,
#    'end': True,
#    'fag': True,
#    'pub': True,
#    'bum': True},
#   'Non-Bullying'),
#  ({'get': True,
#    'home': True,
#    'surprised': True,
#    'new': True,
#    'toy': True,
#    'feel': True,
#    'fucking': True,
#    'good': True,
#    'pussy': True,
#    'vibrator': True,
#    'cum': True,
#    'thirstythursday': True,
#    'ho': True},
#   'Non-Bullying'),
#  ({'..dloesch': True,
#    'human': True,
#    'homo': True,
#    'sapians': True,
#    "'could": True,
#    'rather': True,
#    'specimen': True,
#    'dumbass': True,
#    'bitcheness': True},
#   'Bullying'),
#  ({'..shelteringwind': True,
#    '.xeronius': True,
#    '.theintercept': True,
#    'add': True,
#    'low': True,
#    'iq': True,
#    'conspiracy': True,
#    'theorist': True,
#    'mix': True},
#   'Non-Bullying'),
#  ({'hey': True,
#    'jethro': True,
#    "'re": True,
#    'cry': True,
#    "'why": True,
#    "'everyone": True,
#    'know': True,
#    'b': True},
#   'Bullying'),
#  ({'feminism': True}, 'Non-Bullying'),
#  ({'nobody': True,
#    'memphis': True,
#    'care': True,
#    "'you": True,
#    'worry': True,
#    'coach': True,
#    'cal': True,
#    'getting': True,
#    'talent': True,
#    'wasting': True,
#    'it..': True},
#   'Non-Bullying'),
#  ({'realjameswoods': True, 'obama': True, 'support': True, 'nazi': True},
#   'Non-Bullying'),
#  ({'.my': True,
#    'dumbass': True,
#    'forgot': True,
#    'work': True,
#    'uniform': True,
#    'bed..': True,
#    'first': True,
#    'time': True,
#    'ever': True,
#    'done': True,
#    'shit': True,
#    "'now": True,
#    'got': True,
#    'ta': True,
#    'wear': True,
#    'hospital': True,
#    'scrub': True,
#    "'hella": True,
#    'weird': True,
#    '\\u200d': True},
#   'Non-Bullying'),
#  ({'tonight': True,
#    'class': True,
#    'discussion': True,
#    'gender': True,
#    'based': True,
#    'racial': True,
#    'oppression': True,
#    'black': True,
#    'america': True,
#    "'the": True,
#    'impact': True,
#    'patriarchy': True,
#    'misandry': True},
#   'Non-Bullying'),
#  ({'talk': True, 'nahh': True, '..we': True, 'ruining': True, 'life': True},
#   'Non-Bullying'),
#  ({'.realdonaldtrump': True,
#    'nothing': True,
#    'dumbass': True,
#    'trump': True,
#    'say': True,
#    'make': True,
#    'sense': True,
#    "'his": True,
#    'i.q': True,
#    "'must": True,
#    'chart': True,
#    'wrong': True,
#    'direction..': True},
#   'Bullying'),
#  ({'conor': True,
#    'fucking': True,
#    'deported': True,
#    'rate': True,
#    'grade': True,
#    'cunt': True,
#    'guy': True,
#    'throwing': True,
#    'boomerang': True,
#    'racist': True},
#   'Bullying'),
#  ({'piece': True,
#    'shit': True,
#    'leave': True,
#    'america': True,
#    'worthless': True,
#    'human': True,
#    'wishing': True,
#    'death': True,
#    'anyone': True,
#    'make': True,
#    'coward': True},
#   'Bullying'),
#  ({'say': True,
#    'someone': True,
#    'try': True,
#    'mansplain': True,
#    'away': True,
#    'gender': True,
#    'pay': True,
#    'gap': True,
#    '.anoosh.c': True},
#   'Non-Bullying'),
#  ({'.things': True,
#    'nobody': True,
#    'care': True,
#    'snapchat/instagram': True,
#    'story': True,
#    'meal': True,
#    'workout': True,
#    'perfect': True,
#    'bf': True},
#   'Non-Bullying'),
#  ({'want': True,
#    'called': True,
#    'goatfucker': True,
#    'photoshop': True,
#    'fucking': True,
#    'goat..': True},
#   'Non-Bullying'),
#  ({'really': True,
#    'think': True,
#    'crazy': True,
#    'many': True,
#    'people': True,
#    'including': True,
#    'alpha': True,
#    'assume': True,
#    'u': True,
#    'goddess': True,
#    'roxy': True,
#    'husband': True},
#   'Non-Bullying'),
#  ({'.honestly': True, 'assed': True, 'photography': True, 'ky': True},
#   'Non-Bullying'),
#  ({'tim': True,
#    'mccarver': True,
#    'idiot': True,
#    'pick': True,
#    '2-0': True,
#    'know': True,
#    'pitcher': True,
#    'throwing': True,
#    'hard': True,
#    "'how": True,
#    'gon': True,
#    'na': True,
#    'pi': True},
#   'Non-Bullying'),
#  ({'fugly': True}, 'Non-Bullying'),
#  ({'idfspokesperson': True,
#    'yes': True,
#    'poor': True,
#    'picture': True,
#    'coward': True,
#    'goatfucker': True},
#   'Bullying'),
#  ({'mean': True,
#    'lot': True,
#    'people': True,
#    'look': True,
#    'porn': True,
#    'good': True,
#    'weebo': True,
#    'messed': True},
#   'Non-Bullying'),
#  ({'good': True,
#    'sir': True,
#    'baptized': True,
#    "'go": True,
#    'forth': True,
#    'argue': True,
#    'internet': True,
#    "'gaming": True,
#    'atheism': True,
#    'feminism': True,
#    'anime': True,
#    'domain..': True},
#   'Non-Bullying'),
#  ({'khabib': True,
#    '20': True,
#    'russian': True,
#    'travel': True,
#    'alone': True,
#    "'these": True,
#    'tra': True},
#   'Non-Bullying'),
#  ({'ingrahamangle': True,
#    'foxnews': True,
#    'fucking': True,
#    'retard': True,
#    "'.davidhogg111": True},
#   'Bullying'),
#  ({'bwahahaaa': True,
#    "'dumbass": True,
#    'oklahoma': True,
#    'gop': True,
#    'lawmaker': True,
#    'say': True,
#    '25': True,
#    'percent': True,
#    'teacher': True,
#    'protestors': True,
#    'paid': True,
#    'actor': True,
#    'bussed': True,
#    'chicago': True,
#    'h': True},
#   'Non-Bullying'),
#  ({'low': True,
#    'iq': True,
#    'someone': True,
#    'help': True,
#    'muslim': True,
#    'ever': True,
#    'race..': True},
#   'Bullying'),
#  ({'..5ile': True, 'nigger': True}, 'Non-Bullying'),
#  ({'also': True, 'next': True, 'time': True, 'dumbass': True}, 'Non-Bullying'),
#  ({'he': True, 'goatfucker': True}, 'Non-Bullying'),
#  ({'trump': True, 'idiot': True, 'senator': True}, 'Bullying'),
#  ({'fbi': True,
#    'raid': True,
#    'home': True,
#    'connected': True,
#    'crazed': True,
#    'nazi': True,
#    'larper': True,
#    'jordan': True,
#    'jereb': True,
#    'man': True,
#    'claimed': True,
#    'parkland': True,
#    'shooter': True,
#    'nikolas': True,
#    'cruz': True,
#    'trained': True},
#   'Non-Bullying'),
#  ({'low': True, 'iq': True, 'crime': True, "'simple": True}, 'Non-Bullying'),
#  ({'possible': True,
#    'response': True,
#    'given': True,
#    'fitinorfuckoff': True,
#    'f-off': True,
#    "'ll": True,
#    'pay': True,
#    'airfare': True,
#    'one': True,
#    'goatfucker': True},
#   'Bullying'),
#  ({'fugly': True, 'friend': True, "'funny": True, 'ugly': True},
#   'Non-Bullying'),
#  ({'retweet': True, 'think': True, '.mrpatriarch12': True, 'nazi..': True},
#   'Bullying'),
#  ({'.and': True,
#    'there': True,
#    'like': True,
#    '20': True,
#    'people': True,
#    'claimin': True,
#    'one': True,
#    'ov': True,
#    'fb': True,
#    'status': True,
#    'bout': True,
#    'xd': True,
#    'round': True,
#    'ear': True,
#    'make': True,
#    'chuckle': True},
#   'Non-Bullying'),
#  ({'u': True,
#    'bitter': True,
#    'ur': True,
#    'pathetic': True,
#    'fat': True,
#    'slob': True,
#    'sore': True,
#    'parent': True,
#    'raised': True,
#    'sad': True,
#    'pat': True},
#   'Bullying'),
#  ({'..paulsmithjnr': True,
#    'sportsman': True,
#    'loved': True,
#    'watching': True,
#    'stage': True,
#    'kid': True,
#    'pint': True,
#    'fag': True,
#    'hand': True,
#    'magician': True},
#   'Non-Bullying'),
#  ({'.omg': True,
#    'poc': True,
#    'wearing': True,
#    'fugly': True,
#    'blue': True,
#    'contact': True,
#    '2018.': True,
#    'please': True,
#    'make': True,
#    'stop': True},
#   'Non-Bullying'),
#  ({'sxdlymxdi': True,
#    'cunt': True,
#    'as': True,
#    'mother': True,
#    'fucking': True,
#    'bitch': True,
#    "'happy": True},
#   'Bullying'),
#  ({'theellenshow': True,
#    '.kamalaharris': True,
#    'yeah': True,
#    'worthless': True,
#    'piece': True,
#    'shit': True,
#    "'you": True,
#    'thought': True,
#    'joke': True,
#    'killing': True,
#    'president': True,
#    'f': True},
#   'Bullying'),
#  ({'.oh': True,
#    'god': True,
#    'fuck': True,
#    'love': True,
#    'park': True,
#    'amp': True,
#    'rec': True,
#    "'and": True,
#    'casted': True,
#    'nct': True,
#    'member': True,
#    'perfectly': True},
#   'Non-Bullying'),
#  ({'many': True,
#    'u': True,
#    'jewish': True,
#    'left': True,
#    'trans': True,
#    'make': True,
#    'room': True,
#    'prejudice': True,
#    'community': True},
#   'Non-Bullying'),
#  ({'bron': True,
#    'blocking': True,
#    'shot': True,
#    'fxckin': True,
#    'dumbass': True,
#    'dunk': True,
#    'ball': True},
#   'Non-Bullying'),
#  ({'many': True,
#    'irishman': True,
#    'serving': True,
#    'u': True,
#    'army': True,
#    'mexican-american': True,
#    'war': True,
#    'experienced': True,
#    'racism': True,
#    'anti-catholic': True,
#    'prejudice': True},
#   'Non-Bullying'),
#  ({'.i': True,
#    'miss': True,
#    '.h0eslovebree': True,
#    'fugly': True,
#    'booty': True,
#    'as': True,
#    "'dont": True,
#    'nobody': True,
#    'laugh': True,
#    'dumb': True,
#    'shit': True,
#    'w/': True},
#   'Bullying'),
#  ({'guess': True,
#    'suicide': True,
#    'bomber': True,
#    'spread': True,
#    'love': True,
#    'standard': True,
#    'goatfucker': True},
#   'Bullying'),
#  ({'.can': True,
#    'trend': True,
#    'backpack': True,
#    'stay': True,
#    'primary': True,
#    'school': True,
#    'plz': True,
#    'fugly': True},
#   'Non-Bullying'),
#  ({'.anyone': True,
#    'uk': True,
#    'phone': True,
#    'help': True,
#    'accept': True,
#    'total': True,
#    'loser': True,
#    'pay': True,
#    'keep': True,
#    'awake': True,
#    'make': True,
#    'mo': True},
#   'Non-Bullying'),
#  ({'goatfucker': True, 'eat': True, 'shit': True, 'die': True}, 'Bullying'),
#  ({'seanhannity': True,
#    '.realdonaldtrump': True,
#    'many': True,
#    'people': True,
#    'think': True,
#    'libtard': True,
#    'moron': True},
#   'Bullying'),
#  ({'seanhannity': True,
#    'creative': True,
#    'kermie': True,
#    "'ve": True,
#    'seen': True,
#    'gif': True,
#    'couple': True,
#    'thousan': True},
#   'Non-Bullying'),
#  ({'fuck': True}, 'Bullying'),
#  ({'everyday': True,
#    "'m": True,
#    'call': True,
#    'whore': True,
#    'goatfucker': True,
#    'bitch': True,
#    'etc..': True,
#    'nobody': True,
#    'get': True,
#    'suspended': True,
#    'force': True,
#    'remove': True},
#   'Bullying'),
#  ({'entire': True,
#    'career': True,
#    'focused': True,
#    'challenging': True,
#    'male': True,
#    'violence': True,
#    'woman': True,
#    'exploitative': True,
#    'system': True,
#    'like': True,
#    'prostitution': True,
#    'th': True},
#   'Non-Bullying'),
#  ({'trans': True,
#    'woman': True,
#    'make': True,
#    'inherently': True,
#    'dangerous': True,
#    'ci': True,
#    "'th": True},
#   'Non-Bullying'),
#  ({'realdonaldtrump': True,
#    'start': True,
#    'trade': True,
#    'war': True,
#    'nothing': True,
#    'worthless': True,
#    'racist': True,
#    'lying': True,
#    'piece': True,
#    'shit': True,
#    "'you": True,
#    'shou': True},
#   'Bullying'),
#  ({'doubt': True,
#    'bloke': True,
#    'life': True,
#    'britain..': True,
#    'guess': True,
#    'make': True,
#    'prejudice': True,
#    'cunt': True},
#   'Bullying'),
#  ({'lil': True,
#    'nigga': True,
#    'better': True,
#    'mind': True,
#    'say': True,
#    'little': True,
#    'fuck': True,
#    'boy': True},
#   'Bullying'),
#  ({'*beside': True,
#    "'like": True,
#    'imagine': True,
#    'thinking': True,
#    'acceptable': True,
#    "'bc": True,
#    'letter': True,
#    'end': True,
#    "'straight": True,
#    'ppl': True,
#    'next': True,
#    'week': True,
#    'gon': True,
#    'na': True,
#    'saying': True,
#    'well': True},
#   'Non-Bullying'),
#  ({'.realdonaldtrump': True,
#    'call': True,
#    'bullshit': True,
#    'presidentshit4brains': True,
#    "'you": True,
#    'worthless': True,
#    'piece': True,
#    'shit': True,
#    'con': True,
#    'artist': True,
#    'lowest': True},
#   'Bullying'),
#  ({'one': True,
#    'fugly': True,
#    'bitch': True,
#    "'all": True,
#    'look': True,
#    'rode': True,
#    'hard': True,
#    'hung': True,
#    'dry': True},
#   'Bullying'),
#  ({'..realdonaldtrump': True,
#    'unicorn': True,
#    'poop': True,
#    'rainbow': True,
#    'alternate': True,
#    'reality': True,
#    "'the": True,
#    'caravan': True,
#    'broken': True,
#    'n': True},
#   'Non-Bullying'),
#  ({"'re": True,
#    'guy': True,
#    'feel': True,
#    'metoo': True,
#    'movement': True,
#    'preventing': True,
#    'flirting': True,
#    'possible': True,
#    'never': True,
#    'actually': True},
#   'Non-Bullying'),
#  ({'lmao': True,
#    '.no': True,
#    'spiritual': True,
#    'right': True,
#    'wing': True,
#    'wa': True},
#   'Non-Bullying'),
#  ({'.italian': True,
#    'chabby': True,
#    'fuck': True,
#    'blogspots': True,
#    'homosexual': True,
#    'prejudice': True},
#   'Bullying'),
#  ({'.a': True,
#    'nazi': True,
#    'troll': True,
#    'outed': True,
#    'extreme': True,
#    'right': True,
#    'in-fight': True,
#    "'he": True,
#    'call': True,
#    'alt-right': True,
#    'buy': True},
#   'Bullying'),
#  ({'.shout': True,
#    'amazon': True,
#    'reviewer': True,
#    'enjoyed': True,
#    'book': True,
#    'felt': True,
#    'much': True,
#    'liberalism': True,
#    'feminism': True,
#    '..': True},
#   'Non-Bullying'),
#  ({'sure': True,
#    'jajajajaja': True,
#    "'re": True,
#    'fucking': True,
#    'bastard': True,
#    'liar': True,
#    'retard': True,
#    'muslim': True,
#    'w': True},
#   'Bullying'),
#  ({'matter': True,
#    "'not": True,
#    'dude': True,
#    'skin': True,
#    'color': True,
#    'ok': True,
#    'bad': True,
#    'b': True},
#   'Non-Bullying'),
#  ({'iwan': True,
#    'numerous': True,
#    'cast': True,
#    'member': True,
#    'also': True,
#    'said': True,
#    'asshole': True,
#    'outside': True,
#    "'guess": True,
#    'ju': True},
#   'Non-Bullying'),
#  ({'lmao': True, 'going': True, 'asshole': True, 'people': True}, 'Bullying'),
#  ({'max': True,
#    'laura': True,
#    'fucking': True,
#    'stop': True,
#    'youre': True,
#    'overdramatic': True,
#    'asshole': True,
#    'say': True,
#    'dumb': True,
#    'shit': True,
#    'like': True,
#    'bc': True,
#    'kn': True},
#   'Bullying'),
#  ({'video': True,
#    'inside': True,
#    'city': True,
#    'bus': True,
#    'anfield': True,
#    "'city": True,
#    'coaching': True,
#    'staff': True,
#    'saying': True,
#    'thinking': True,
#    'fucking': True},
#   'Non-Bullying'),
#  ({'.yeah': True,
#    'i\\': True,
#    "'m": True,
#    'fag': True,
#    'real': True,
#    'deal': True,
#    'dyke': True,
#    'filthy': True,
#    'homosexual': True,
#    "'get": True,
#    'fuck': True,
#    'megalomaniacal': True,
#    'idiot..': True},
#   'Non-Bullying'),
#  ({'fucking': True, 'cunt': True}, 'Bullying'),
#  ({'.lol': True,
#    'main': True,
#    'koi': True,
#    'celeb': True,
#    'hu': True,
#    'kiya': True,
#    'jo': True,
#    'mujhe': True,
#    'support': True,
#    'karoge': True,
#    'btw': True,
#    'flopsstar': True,
#    'defeated': True,
#    'murderer\\': True,
#    'fugly': True,
#    'as': True},
#   'Non-Bullying'),
#  ({'feel': True,
#    'rdj': True,
#    'blackface': True,
#    'tropic': True,
#    'thunder': True,
#    'honorary': True,
#    'nigger': True,
#    "'he": True,
#    'everyone': True,
#    'thinking': True,
#    'blac': True},
#   'Non-Bullying'),
#  ({'weird': True,
#    'argument': True,
#    'trying': True,
#    'prove': True,
#    'salman': True,
#    'khan': True,
#    'would': True,
#    'kill': True,
#    'rhino': True,
#    'assam': True,
#    'elephant': True,
#    'kere': True},
#   'Bullying'),
#  ({'rolling': True,
#    'wasting': True,
#    'money': True,
#    'wrap': True,
#    '.gluntofficial': True,
#    'game': True,
#    'changer': True},
#   'Non-Bullying'),
#  ({'dloesch': True,
#    'yeah': True,
#    'sure': True,
#    'god': True,
#    'approves': True,
#    'bullying': True,
#    'serial': True,
#    'cheating': True,
#    'lying': True,
#    'pussy': True,
#    'grabbin': True},
#   'Bullying'),
#  ({'omg': True,
#    '.kissasins': True,
#    'sexy': True,
#    'delicious': True,
#    "'you": True,
#    'amazing': True,
#    'booty': True,
#    'smile': True,
#    'tit': True,
#    'shave': True,
#    'pussy': True},
#   'Non-Bullying'),
#  ({'fag': True}, 'Bullying'),
#  ({'realjameswoods': True,
#    'oh': True,
#    'god': True,
#    'pussy': True,
#    'pick': True,
#    'current': True,
#    'archaeolo': True},
#   'Bullying'),
#  ({'.nude': True,
#    'egypt': True,
#    'girl': True,
#    'teen': True,
#    'cunt': True,
#    'fucking': True},
#   'Non-Bullying'),
#  ({'gone': True, 'fight': True, 'see': True}, 'Bullying'),
#  ({'dumbass': True,
#    'tried': True,
#    'text': True,
#    'bitch': True,
#    'blocked': True},
#   'Non-Bullying'),
#  ({'middle': True,
#    'easterner': True,
#    'grouped': True,
#    'white': True,
#    'people': True,
#    'ethnic': True,
#    'section': True,
#    'application': True,
#    'really': True,
#    'funny': True,
#    'bc': True},
#   'Non-Bullying'),
#  ({'listen': True,
#    'kid': True,
#    'know': True,
#    'u': True,
#    'want': True,
#    'stop': True,
#    'getting': True,
#    'violently': True,
#    'murdered': True,
#    'assault': True,
#    'rifle': True,
#    'need': True,
#    'grow': True,
#    'realize': True},
#   'Non-Bullying'),
#  ({'solicit': True,
#    'yours.': True,
#    'retard': True,
#    'think': True,
#    'perhaps': True,
#    'are..': True},
#   'Bullying'),
#  ({'love': True,
#    'doughy': True,
#    'cynical': True,
#    'cowardly': True,
#    'poseur': True,
#    'unimaginative': True,
#    'retro-grade': True,
#    'faux-christ': True},
#   'Non-Bullying'),
#  ({'happened': True, 'enravish': True, 'kid': True, 'fag': True, 'lol': True},
#   'Bullying'),
#  ({'stereotyping': True, 'gay': True, 'men': True, 'said': True, 'b': True},
#   'Non-Bullying'),
#  ({'surely': True,
#    'know': True,
#    'thats': True,
#    'problem': True,
#    "'the": True,
#    'low': True,
#    'variance': True,
#    'captured': True,
#    'gwa': True,
#    'iq': True,
#    'study': True,
#    'social': True,
#    'class': True,
#    'diff': True},
#   'Non-Bullying'),
#  ({'thomassanders': True, 'love': True, 'deserve': True}, 'Non-Bullying'),
#  ({'instead': True,
#    'sitting': True,
#    'around': True,
#    'day': True,
#    'mad': True,
#    'truth': True,
#    'analyze': True,
#    'trigger': True},
#   'Non-Bullying'),
#  ({'.jimmykimmel': True,
#    'forget': True,
#    'speaks': True,
#    '5': True,
#    'language': True,
#    'many': True,
#    'speak': True,
#    'maybe': True,
#    'spanish': True,
#    'low': True,
#    'iq': True},
#   'Bullying'),
#  ({'slow': True,
#    'retard': True,
#    'made': True,
#    'point': True,
#    'without': True,
#    'kyire': True,
#    'hurtvin': True,
#    'trade': True,
#    'cavs': True,
#    'wo': True,
#    'gotten': True,
#    'youn': True},
#   'Non-Bullying')]

# %%
nb_classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
from nltk.classify.util import accuracy

# %%
print(accuracy(nb_classifier, test_set))
# Out:
# 0.6698113207547169

# %%
refsets = collections.defaultdict(set)
testsets = collections.defaultdict(set)

# %%
wlabels = []
wtests = []
for i, (Final_Data, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = nb_classifier.classify(Final_Data)
    testsets[observed].add(i)
    wlabels.append(label)
    wtests.append(observed)

# %%
cm = ConfusionMatrix(wlabels, wtests)
print(cm)
# Out:
#              |       N |
#              |       o |
#              |       n |
#              |       - |
#              |   B   B |
#              |   u   u |
#              |   l   l |
#              |   l   l |
#              |   y   y |
#              |   i   i |
#              |   n   n |
#              |   g   g |
# -------------+---------+
#     Bullying | <88> 43 |
# Non-Bullying |  62<125>|
# -------------+---------+
# (row = reference; col = test)

# %%
print('bullying precision:', precision(refsets['Bullying'], testsets['Bullying']))
print('bullying recall:', recall(refsets['Bullying'], testsets['Bullying']))
print('bullying F-measure:', f_measure(refsets['Bullying'], testsets['Bullying']))
print('not-bullying precision:', precision(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('not-bullying recall:', recall(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('not-bullying F-measure:', f_measure(refsets['Non-Bullying'], testsets['Non-Bullying']))
# Out:
# bullying precision: 0.5866666666666667
# bullying recall: 0.6717557251908397
# bullying F-measure: 0.6263345195729537
# not-bullying precision: 0.7440476190476191
# not-bullying recall: 0.6684491978609626
# not-bullying F-measure: 0.7042253521126761

# %%
dt_classifier = DecisionTreeClassifier.train(train_set, 
                                             binary=True, 
                                             entropy_cutoff=0.8, 
                                             depth_cutoff=5, 
                                             support_cutoff=30)

# %%
print(accuracy(dt_classifier, test_set))
# Out:
# 0.6415094339622641

# %%
refsets = collections.defaultdict(set)
testsets = collections.defaultdict(set)

# %%
wlabels = []
wtests = []
for i, (Final_Data, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = dt_classifier.classify(Final_Data)
    testsets[observed].add(i)
    wlabels.append(label)
    wtests.append(observed)

# %%
cm = ConfusionMatrix(wlabels, wtests)
print(cm)
# Out:
#              |       N |
#              |       o |
#              |       n |
#              |       - |
#              |   B   B |
#              |   u   u |
#              |   l   l |
#              |   l   l |
#              |   y   y |
#              |   i   i |
#              |   n   n |
#              |   g   g |
# -------------+---------+
#     Bullying | <41> 90 |
# Non-Bullying |  24<163>|
# -------------+---------+
# (row = reference; col = test)

# %%
print('bullying precision:', precision(refsets['Bullying'], testsets['Bullying']))
print('bullying recall:', recall(refsets['Bullying'], testsets['Bullying']))
print('bullying F-measure:', f_measure(refsets['Bullying'], testsets['Bullying']))
print('non-bullying precision:', precision(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('non-bullying recall:', recall(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('non-bullying F-measure:', f_measure(refsets['Non-Bullying'], testsets['Non-Bullying']))
# Out:
# bullying precision: 0.6307692307692307
# bullying recall: 0.31297709923664124
# bullying F-measure: 0.41836734693877553
# non-bullying precision: 0.6442687747035574
# non-bullying recall: 0.8716577540106952
# non-bullying F-measure: 0.740909090909091

# %%
logit_classifier = MaxentClassifier.train(train_set, algorithm='gis', trace=0, max_iter=10, min_lldelta=0.5)

# %%
wlabels = []
wtests = []
for i, (Final_Data, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = logit_classifier.classify(Final_Data)
    testsets[observed].add(i)
    wlabels.append(label)
    wtests.append(observed)

# %%
cm = ConfusionMatrix(wlabels, wtests)
print(cm)
# Out:
#              |       N |
#              |       o |
#              |       n |
#              |       - |
#              |   B   B |
#              |   u   u |
#              |   l   l |
#              |   l   l |
#              |   y   y |
#              |   i   i |
#              |   n   n |
#              |   g   g |
# -------------+---------+
#     Bullying | <64> 67 |
# Non-Bullying |  32<155>|
# -------------+---------+
# (row = reference; col = test)

# %%
print('Bullying  precision:', precision(refsets['Bullying'], testsets['Bullying']))
print('Bullying  recall:', recall(refsets['Bullying'], testsets['Bullying']))
print('Bullying  F-measure:', f_measure(refsets['Bullying'], testsets['Bullying']))
print('Non-Bullying precision:', precision(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('Non-Bullying recall:', recall(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('Non-Bullying F-measure:', f_measure(refsets['Non-Bullying'], testsets['Non-Bullying']))
# Out:
# Bullying  precision: 0.6302521008403361
# Bullying  recall: 0.5725190839694656
# Bullying  F-measure: 0.6
# Non-Bullying precision: 0.6340579710144928
# Non-Bullying recall: 0.9358288770053476
# Non-Bullying F-measure: 0.7559395248380131

# %%
SVM_classifier = SklearnClassifier(SVC(), sparse=False).train(train_set)

# %%
wlabels = []
wtests = []
for i, (Final_Data, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = SVM_classifier.classify(Final_Data)
    testsets[observed].add(i)
    wlabels.append(label)
    wtests.append(observed)

# %%
cm = ConfusionMatrix(wlabels, wtests)
print(cm)
# Out:
#              |       N |
#              |       o |
#              |       n |
#              |       - |
#              |   B   B |
#              |   u   u |
#              |   l   l |
#              |   l   l |
#              |   y   y |
#              |   i   i |
#              |   n   n |
#              |   g   g |
# -------------+---------+
#     Bullying | <72> 59 |
# Non-Bullying |  37<150>|
# -------------+---------+
# (row = reference; col = test)

# %%
print('Bullying precision:', precision(refsets['Bullying'], testsets['Bullying']))
print('Bullying recall:', recall(refsets['Bullying'], testsets['Bullying']))
print('Bullying F-measure:', f_measure(refsets['Bullying'], testsets['Bullying']))
print('Non-Bullying precision:', precision(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('Non-Bullying recall:', recall(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('Non-Bullying F-measure:', f_measure(refsets['Non-Bullying'], testsets['Non-Bullying']))
# Out:
# Bullying precision: 0.6044776119402985
# Bullying recall: 0.6183206106870229
# Bullying F-measure: 0.6113207547169811
# Non-Bullying precision: 0.631768953068592
# Non-Bullying recall: 0.9358288770053476
# Non-Bullying F-measure: 0.7543103448275863

# %%
zl = zip(Tweet,Labels)

# %%
def bag_of_words(words):
    return dict([(word, True) for word in words])

# %%
def bag_of_words_not_in_set(words, badwords):
    return bag_of_words(set(words) - set(badwords))

# %%
def bag_of_non_stopwords(words, stopfile='english'):
    badwords = stopwords.words(stopfile)
    return bag_of_words_not_in_set(words, badwords)

# %%
def bag_of_bigrams_words(words, score_fn=BigramAssocMeasures.chi_sq, n=200):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    return bag_of_words(bigrams)
    
    bigrams = bag_of_bigrams_words(words)

# %%
Final_Data = []

# %%
for k, v in zl:
    bag_of_bigrams_words(k)
    Final_Data.append((bag_of_bigrams_words(k),v))

# %%
random.shuffle(Final_Data)

# %%
train_set, test_set = Final_Data[0:778], Final_Data[778:]

# %%
nb_classifier = nltk.NaiveBayesClassifier.train(train_set)
nb_classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#            ('low', 'iq') = True           Bullyi : Non-Bu =     10.0 : 1.0
#        ('piece', 'shit') = True           Bullyi : Non-Bu =      8.9 : 1.0
#   ('worthless', 'piece') = True           Bullyi : Non-Bu =      6.0 : 1.0
#            ('gon', 'na') = True           Bullyi : Non-Bu =      3.3 : 1.0
#    ('pathetic', 'loser') = True           Bullyi : Non-Bu =      2.6 : 1.0
# ('theellenshow', '.kamalaharris') = True           Bullyi : Non-Bu =      2.4 : 1.0
#    ('fucking', 'retard') = True           Bullyi : Non-Bu =      2.4 : 1.0
#        ('smell', 'like') = True           Bullyi : Non-Bu =      2.4 : 1.0
#           ('dumb', 'as') = True           Bullyi : Non-Bu =      2.4 : 1.0
#            ('i\\', "'m") = True           Non-Bu : Bullyi =      1.5 : 1.0

# %%
print(accuracy(nb_classifier, test_set))
# Out:
# 0.627177700348432

# %%
refsets = collections.defaultdict(set)
testsets = collections.defaultdict(set)

# %%
for i, (Final_Data, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = nb_classifier.classify(Final_Data)
    testsets[observed].add(i)

# %%
print('bullying precision:', precision(refsets['Bullying'], testsets['Bullying']))
print('bullying recall:', recall(refsets['Bullying'], testsets['Bullying']))
print('bullying F-measure:', f_measure(refsets['Bullying'], testsets['Bullying']))
print('not-bullying precision:', precision(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('not-bullying recall:', recall(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('not-bullying F-measure:', f_measure(refsets['Non-Bullying'], testsets['Non-Bullying']))
# Out:
# bullying precision: 0.5
# bullying recall: 0.2336448598130841
# bullying F-measure: 0.3184713375796178
# not-bullying precision: 0.6540084388185654
# not-bullying recall: 0.8611111111111112
# not-bullying F-measure: 0.7434052757793764

# %%
def bigrams_words(words, score_fn=BigramAssocMeasures.chi_sq, n=200):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    return bigrams

# %%
def trigrams_words(words, score_fn=TrigramAssocMeasures.chi_sq, n=200):
    trigram_finder = TrigramCollocationFinder.from_words(words)
    trigrams = trigram_finder.nbest(score_fn, n)
    return trigrams

# %%
def bag_of_Ngrams_words(words):
    bigramBag = bigrams_words(words)
    
    #The following two for loops convert tuple into string
    for b in range(0,len(bigramBag)):
        bigramBag[b]=' '.join(bigramBag[b])
   
    trigramBag = trigrams_words(words)
    for t in range(0,len(trigramBag)):
        trigramBag[t]=' '.join(trigramBag[t])

    return bag_of_words(trigramBag + bigramBag + words)

# %%
zl = zip(Tweet,Labels)

# %%
Final_Data = []

# %%
for k, v in zl:
    bag_of_words(k)
    Final_Data.append((bag_of_words(k),v))

# %%
random.shuffle(Final_Data)

# %%
train_set, test_set = Final_Data[0:778], Final_Data[778:]

# %%
nb_classifier = nltk.NaiveBayesClassifier.train(train_set)
nb_classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#                    mouth = True           Bullyi : Non-Bu =      7.4 : 1.0
#                      amp = True           Non-Bu : Bullyi =      7.0 : 1.0
#                      low = True           Bullyi : Non-Bu =      6.9 : 1.0
#                    piece = True           Bullyi : Non-Bu =      6.6 : 1.0
#             goatfucker.. = True           Bullyi : Non-Bu =      6.4 : 1.0
#                worthless = True           Bullyi : Non-Bu =      6.2 : 1.0
#                    sorry = True           Bullyi : Non-Bu =      5.4 : 1.0
#                  libtard = True           Bullyi : Non-Bu =      5.3 : 1.0
#                 feminism = True           Non-Bu : Bullyi =      5.0 : 1.0
#                     cunt = True           Bullyi : Non-Bu =      4.8 : 1.0

# %%
print(accuracy(nb_classifier, test_set))
# Out:
# 0.6759581881533101

# %%
refsets = collections.defaultdict(set)
testsets = collections.defaultdict(set)

# %%
for i, (Final_Data, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = nb_classifier.classify(Final_Data)
    testsets[observed].add(i)

# %%
print('bullying precision:', precision(refsets['Bullying'], testsets['Bullying']))
print('bullying recall:', recall(refsets['Bullying'], testsets['Bullying']))
print('bullying F-measure:', f_measure(refsets['Bullying'], testsets['Bullying']))
print('not-bullying precision:', precision(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('not-bullying recall:', recall(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('not-bullying F-measure:', f_measure(refsets['Non-Bullying'], testsets['Non-Bullying']))
# Out:
# bullying precision: 0.5853658536585366
# bullying recall: 0.631578947368421
# bullying F-measure: 0.6075949367088607
# not-bullying precision: 0.7439024390243902
# not-bullying recall: 0.7052023121387283
# not-bullying F-measure: 0.7240356083086052

# %%
dt_classifier = DecisionTreeClassifier.train(train_set, 
                                             binary=True, 
                                             entropy_cutoff=0.8, 
                                             depth_cutoff=5, 
                                             support_cutoff=30)

# %%
print(accuracy(dt_classifier, test_set))
# Out:
# 0.6689895470383276

# %%
refsets = collections.defaultdict(set)
testsets = collections.defaultdict(set)

# %%
for i, (Final_Data, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = dt_classifier.classify(Final_Data)
    testsets[observed].add(i)

# %%
print('bullying precision:', precision(refsets['Bullying'], testsets['Bullying']))
print('bullying recall:', recall(refsets['Bullying'], testsets['Bullying']))
print('bullying F-measure:', f_measure(refsets['Bullying'], testsets['Bullying']))
print('non-bullying precision:', precision(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('non-bullying recall:', recall(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('non-bullying F-measure:', f_measure(refsets['Non-Bullying'], testsets['Non-Bullying']))
# Out:
# bullying precision: 0.7021276595744681
# bullying recall: 0.2894736842105263
# bullying F-measure: 0.40993788819875776
# non-bullying precision: 0.6625
# non-bullying recall: 0.9190751445086706
# non-bullying F-measure: 0.7699757869249394

# %%
logit_classifier = MaxentClassifier.train(train_set, algorithm='gis', trace=0, max_iter=10, min_lldelta=0.5)

# %%
for i, (Final_Data, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = logit_classifier.classify(Final_Data)
    testsets[observed].add(i)

# %%
print('pos precision:', precision(refsets['Bullying'], testsets['Non-Bullying']))
print('pos recall:', recall(refsets['Bullying'], testsets['Non-Bullying']))
print('pos F-measure:', f_measure(refsets['Bullying'], testsets['Non-Bullying']))
print('neg precision:', precision(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('neg recall:', recall(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('neg F-measure:', f_measure(refsets['Non-Bullying'], testsets['Non-Bullying']))
# Out:
# pos precision: 0.3412698412698413
# pos recall: 0.7543859649122807
# pos F-measure: 0.46994535519125685
# neg precision: 0.6587301587301587
# neg recall: 0.9595375722543352
# neg F-measure: 0.7811764705882354

# %%
SVM_classifier = SklearnClassifier(SVC(), sparse=False).train(train_set)

# %%
for i, (Final_Data, label) in enumerate(test_set):
    refsets[label].add(i)
    observed = SVM_classifier.classify(Final_Data)
    testsets[observed].add(i)

# %%
print('pos precision:', precision(refsets['Bullying'], testsets['Bullying']))
print('pos recall:', recall(refsets['Bullying'], testsets['Bullying']))
print('pos F-measure:', f_measure(refsets['Bullying'], testsets['Bullying']))
print('neg precision:', precision(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('neg recall:', recall(refsets['Non-Bullying'], testsets['Non-Bullying']))
print('neg F-measure:', f_measure(refsets['Non-Bullying'], testsets['Non-Bullying']))
# Out:
# pos precision: 0.5692307692307692
# pos recall: 0.6491228070175439
# pos F-measure: 0.6065573770491803
# neg precision: 0.6600790513833992
# neg recall: 0.9653179190751445
# neg F-measure: 0.7840375586854459

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from tensorflow.keras.models import Model

# %%
from tensorflow.keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
from tensorflow.keras.preprocessing import sequence

# %%
from tensorflow.keras.utils import to_categorical

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
df1 = pd.read_csv("CyberBullyingDataset.csv",delimiter=',',encoding='latin-1')

# %%
df1.head()
# Out:
#                                                Tweet    Text Label
# 0  .omg why are poc wearing fugly blue contacts s...  Non-Bullying
# 1  .Sorry but most of the runners popular right n...  Non-Bullying
# 2  .those jeans are hideous, and I?m afraid he?s ...  Non-Bullying
# 3  .I had to dress up for a presentation in class...  Non-Bullying
# 4  .Am I the only one who thinks justin bieber is...  Non-Bullying

# %%
sns.countplot(df1["Text Label"])
plt.xlabel('Text Label')
plt.title('Number of Bullying and Non-Bullying messages')
# Out:
# Text(0.5, 1.0, 'Number of Bullying and Non-Bullying messages')

# %%
X = df1["Tweet"]
Y = df1["Text Label"]
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %%
max_words = 10000
max_len = 1750
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = sequence.pad_sequences(sequences,maxlen=max_len)

# %%
def RNN():
    inputs = Input(name='inputs',shape=[max_len])
    layer = Embedding(max_words,50,input_length=max_len)(inputs)
    layer = LSTM(64)(layer)
    layer = Dense(256,name='FC1')(layer)
    layer = Activation('relu')(layer)
    layer = Dropout(0.5)(layer)
    layer = Dense(1,name='out_layer')(layer)
    layer = Activation('sigmoid')(layer)
    model = Model(inputs=inputs,outputs=layer)
    return model

# %%
model = RNN()
model.summary()
model.compile(loss='binary_crossentropy',optimizer=RMSprop(),metrics=['accuracy'])
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 1750)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, 1750, 50)          500000
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                29440
# _________________________________________________________________
# FC1 (Dense)                  (None, 256)               16640
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 1)                 257
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 546,337
# Trainable params: 546,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(sequences_matrix,Y_train,batch_size=128,epochs=20,
          validation_split=0.2,callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/20
# 6/6 [==============================] - 22s 4s/step - loss: 0.6886 - accuracy: 0.5773 - val_loss: 0.6768 - val_accuracy: 0.6077
# Epoch 2/20
# 6/6 [==============================] - 23s 4s/step - loss: 0.6710 - accuracy: 0.5981 - val_loss: 0.6555 - val_accuracy: 0.6077
# Epoch 3/20
# 6/6 [==============================] - 23s 4s/step - loss: 0.6073 - accuracy: 0.6506 - val_loss: 0.6147 - val_accuracy: 0.6243
# Epoch 4/20
# 6/6 [==============================] - 23s 4s/step - loss: 1.5206 - accuracy: 0.7265 - val_loss: 0.5848 - val_accuracy: 0.7127
# Epoch 5/20
# 6/6 [==============================] - 22s 4s/step - loss: 0.4107 - accuracy: 0.8577 - val_loss: 0.5697 - val_accuracy: 0.7072
# Epoch 6/20
# 6/6 [==============================] - 22s 4s/step - loss: 0.3067 - accuracy: 0.9144 - val_loss: 0.6000 - val_accuracy: 0.6906

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = sequence.pad_sequences(test_sequences,maxlen=max_len)

# %%
accr = model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 5/5 [==============================] - 1s 171ms/step - loss: 0.5442 - accuracy: 0.7250

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# Test set
#   Loss: 0.544
#   Accuracy: 0.725
